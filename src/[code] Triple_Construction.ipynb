# %%
# !pip install -U spacy
# !pip install scispacy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: spacy in /usr/local/lib/python3.7/dist-packages (3.2.4)
# Collecting spacy
#   Using cached spacy-3.3.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.2 MB)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.11.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (4.64.0)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.8.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy) (57.4.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.0.6)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.7)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.0.6)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.21.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.23.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.2)
# Requirement already satisfied: thinc<8.1.0,>=8.0.14 in /usr/local/lib/python3.7/dist-packages (from spacy) (8.0.16)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.0.7)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.9.1)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.10.0.2)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.4.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (21.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.5.18.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.5.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy) (2.0.1)
# Installing collected packages: spacy
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.2.4
#     Uninstalling spacy-3.2.4:
#       Successfully uninstalled spacy-3.2.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scispacy 0.5.0 requires spacy<3.3.0,>=3.2.0, but you have spacy 3.3.0 which is incompatible.
# Successfully installed spacy-3.3.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scispacy in /usr/local/lib/python3.7/dist-packages (0.5.0)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scispacy) (2.23.0)
# Requirement already satisfied: pysbd in /usr/local/lib/python3.7/dist-packages (from scispacy) (0.3.4)
# Requirement already satisfied: scikit-learn>=0.20.3 in /usr/local/lib/python3.7/dist-packages (from scispacy) (1.0.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from scispacy) (1.21.6)
# Requirement already satisfied: conllu in /usr/local/lib/python3.7/dist-packages (from scispacy) (4.4.2)
# Requirement already satisfied: nmslib>=1.7.3.6 in /usr/local/lib/python3.7/dist-packages (from scispacy) (2.1.1)
# Collecting spacy<3.3.0,>=3.2.0
#   Using cached spacy-3.2.4-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.0 MB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from scispacy) (1.1.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from nmslib>=1.7.3.6->scispacy) (5.4.8)
# Requirement already satisfied: pybind11<2.6.2 in /usr/local/lib/python3.7/dist-packages (from nmslib>=1.7.3.6->scispacy) (2.6.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.0.0->scispacy) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.0.0->scispacy) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.0.0->scispacy) (2022.5.18.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.0.0->scispacy) (3.0.4)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.3->scispacy) (1.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.3->scispacy) (3.1.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->scispacy) (4.64.0)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->scispacy) (0.6.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->scispacy) (3.3.0)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->scispacy) (0.4.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->scispacy) (1.8.2)
# Requirement already satisfied: click<8.1.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->scispacy) (7.1.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->scispacy) (2.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->scispacy) (0.9.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->scispacy) (3.0.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->scispacy) (21.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->scispacy) (2.4.3)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->scispacy) (0.4.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->scispacy) (3.0.9)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->scispacy) (8.0.16)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->scispacy) (2.11.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->scispacy) (1.0.7)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->scispacy) (3.10.0.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->scispacy) (2.0.7)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->scispacy) (57.4.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.3.0,>=3.2.0->scispacy) (1.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy<3.3.0,>=3.2.0->scispacy) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy<3.3.0,>=3.2.0->scispacy) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy<3.3.0,>=3.2.0->scispacy) (5.2.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<3.3.0,>=3.2.0->scispacy) (2.0.1)
# Installing collected packages: spacy
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.3.0
#     Uninstalling spacy-3.3.0:
#       Successfully uninstalled spacy-3.3.0
# Successfully installed spacy-3.2.4

# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import spacy
import scispacy
import numpy as np

# %%
from spacy.tokens.doc import Doc
from spacy.tokens.token import Token
from spacy.tokens.span import Span
from pandas.core.frame import DataFrame
from numpy import ndarray

# %%
gena_nlp = spacy.load("en_gena_sm")
gena_nlp.pipeline
# Out:
# /usr/local/lib/python3.7/dist-packages/spacy/util.py:833: UserWarning: [W095] Model 'en_ner_bc5cdr_md' (0.4.0) was trained with spaCy v3.0 and may not be 100% compatible with the current version (3.2.4). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# [('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec at 0x7f4503ab8c90>),
#  ('tagger', <spacy.pipeline.tagger.Tagger at 0x7f43c6fe31a0>),
#  ('attribute_ruler',
#   <spacy.pipeline.attributeruler.AttributeRuler at 0x7f439eab59b0>),
#  ('lemmatizer',
#   <spacy.lang.en.lemmatizer.EnglishLemmatizer at 0x7f439eaf83c0>),
#  ('parser', <spacy.pipeline.dep_parser.DependencyParser at 0x7f439e5eb9d0>),
#  ('entity_ruler', <spacy.pipeline.entityruler.EntityRuler at 0x7f439ea83910>),
#  ('ner', <spacy.pipeline.ner.EntityRecognizer at 0x7f439e5ebcd0>)]

# %% [markdown]
# # Normalize the entities in result file

# %%
results_df = pd.read_csv("gena_data_raw_3.csv")
results_df.head(5)
# Out:
#        PMID                                           Sentence  \
# 0  28470822  Transforming growth factor beta 1 (TGFB1) is d...
# 1  28470822  Transforming growth factor beta 1 (TGFB1) is d...
# 2  28470822  Transforming growth factor beta 1 (TGFB1) is d...
# 3  28470822  Transforming growth factor beta 1 (TGFB1) is d...
# 4  28470822  Transforming growth factor beta 1 (TGFB1) is d...
#
#                                 E1 Type_E1            Relation  \
# 0  Transforming growth factor beta   CHEBI  be dysregulated in
# 1  Transforming growth factor beta   CHEBI  be dysregulated in
# 2  Transforming growth factor beta   CHEBI  be dysregulated in
# 3  Transforming growth factor beta   CHEBI  be dysregulated in
# 4  Transforming growth factor beta   CHEBI  be dysregulated in
#
#                              E2  Type_E2
# 0          subcortical infarcts  DISEASE
# 1  cerebral autosomal recessive  DISEASE
# 2                hereditary SVD  DISEASE
# 3        recessive arteriopathy  DISEASE
# 4           leukoencephalopathy  DISEASE

# %%
# read data
import pandas as pd
papers_df = pd.read_csv("final_papers_3.csv")
full_df = pd.merge(results_df, papers_df, how='left', left_on=['PMID'], right_on=['PMID'])
full_df = full_df[['PMID', 'Sentence', 'Abstract', 'E1', 'Type_E1', 'Relation', 'E2', 'Type_E2']]
full_df.head(50)
# Out:
#         PMID                                           Sentence  \
# 0   28470822  Transforming growth factor beta 1 (TGFB1) is d...
# 1   28470822  Transforming growth factor beta 1 (TGFB1) is d...
# 2   28470822  Transforming growth factor beta 1 (TGFB1) is d...
# 3   28470822  Transforming growth factor beta 1 (TGFB1) is d...
# 4   28470822  Transforming growth factor beta 1 (TGFB1) is d...
# 5   28470822  The aim of this study was to characterize sign...
# 6   31792039  QUESTION 1: What nutritional/metabolic test(s)...
# 7   31792039  QUESTION 1: What nutritional/metabolic test(s)...
# 8   31792039  QUESTION 1: What nutritional/metabolic test(s)...
# 9   31792039  QUESTION 1: What nutritional/metabolic test(s)...
# 10  31792039  QUESTION 1: What nutritional/metabolic test(s)...
# 11  31019473  This is more evident during rapid growth (i.e....
# 12  31019473  Thiamine deficiency contributes to a number of...
# 13  31019473  Thiamine deficiency contributes to a number of...
# 14  31019473  Thiamine deficiency contributes to a number of...
# 15  31019473  Thiamine deficiency contributes to a number of...
# 16  31019473  Thiamine deficiency contributes to a number of...
# 17  31019473  Thiamine deficiency contributes to a number of...
# 18  31019473  Thiamine deficiency contributes to a number of...
# 19  31019473  This review discusses the current knowledge on...
# 20  21453474  This is, to the best of our knowledge, the fir...
# 21  34990378  Bipolar depression typically has a poor respon...
# 22  34990378  The treatment of bipolar depression is based o...
# 23  33564897  The typical cannabis side effects of tiredness...
# 24  33564897  The typical cannabis side effects of tiredness...
# 25  33564897  The typical cannabis side effects of tiredness...
# 26  35179810  Treatment-resistant depression (TRD) is charac...
# 27  35179810  Treatment-resistant depression (TRD) is charac...
# 28  31214863  Although only a few studies have associated RT...
# 29   2865824  Buspirone seems to be as effective as the benz...
# 30   2865824  Buspirone seems to be as effective as the benz...
# 31  10374130  Multiple endocrine neoplasia-type 1 (MEN1) is ...
# 32  10374130  Multiple endocrine neoplasia-type 1 (MEN1) is ...
# 33  10374130  Multiple endocrine neoplasia-type 1 (MEN1) is ...
# 34  10374130  During follow-up, a growing pituitary adenoma ...
# 35  10374130  During follow-up, a growing pituitary adenoma ...
# 36  31244693  Results: The n-3 index negatively correlated w...
# 37  31244693  Results: The n-3 index negatively correlated w...
# 38  31244693  Results: The n-3 index negatively correlated w...
# 39  31244693  The n-6/n-3 PUFA ratio positively correlated w...
# 40  31244693  The n-3 PUFA DHA negatively correlated with th...
# 41  31244693  The n-3 PUFA DHA negatively correlated with th...
# 42  31244693     EPA negatively correlated with manic symptoms.
# 43  31244693  Nervonic acid, an n-9 monounsaturated fatty ac...
# 44  31244693  Nervonic acid, an n-9 monounsaturated fatty ac...
# 45  31244693  Nervonic acid, an n-9 monounsaturated fatty ac...
# 46  31244693  Nervonic acid, an n-9 monounsaturated fatty ac...
# 47  31244693  The long-chain saturated fatty acid tetracosan...
# 48  31244693  The long-chain saturated fatty acid tetracosan...
# 49  31244693  Conclusions: Partially consistent with a previ...
#
#                                              Abstract  \
# 0   Subcortical small vessel disease (SVD) is char...
# 1   Subcortical small vessel disease (SVD) is char...
# 2   Subcortical small vessel disease (SVD) is char...
# 3   Subcortical small vessel disease (SVD) is char...
# 4   Subcortical small vessel disease (SVD) is char...
# 5   Subcortical small vessel disease (SVD) is char...
# 6   A 9-year-old boy presented with a 2-day histor...
# 7   A 9-year-old boy presented with a 2-day histor...
# 8   A 9-year-old boy presented with a 2-day histor...
# 9   A 9-year-old boy presented with a 2-day histor...
# 10  A 9-year-old boy presented with a 2-day histor...
# 11  Thiamine (vitamin B1) is an essential nutrient...
# 12  Thiamine (vitamin B1) is an essential nutrient...
# 13  Thiamine (vitamin B1) is an essential nutrient...
# 14  Thiamine (vitamin B1) is an essential nutrient...
# 15  Thiamine (vitamin B1) is an essential nutrient...
# 16  Thiamine (vitamin B1) is an essential nutrient...
# 17  Thiamine (vitamin B1) is an essential nutrient...
# 18  Thiamine (vitamin B1) is an essential nutrient...
# 19  Thiamine (vitamin B1) is an essential nutrient...
# 20  Autism is a complex neurodevelopmental disorde...
# 21  Depression represents the predominant mood pol...
# 22  Depression represents the predominant mood pol...
# 23  In Germany, physicians who prescribe medical c...
# 24  In Germany, physicians who prescribe medical c...
# 25  In Germany, physicians who prescribe medical c...
# 26  Major depressive disorder (MDD) is a leading c...
# 27  Major depressive disorder (MDD) is a leading c...
# 28  MeCP2 is an X-linked gene; its mutation causes...
# 29  Other methods for the treatment of anxiety are...
# 30  Other methods for the treatment of anxiety are...
# 31  Multiple endocrine neoplasia-type 1 (MEN1) is ...
# 32  Multiple endocrine neoplasia-type 1 (MEN1) is ...
# 33  Multiple endocrine neoplasia-type 1 (MEN1) is ...
# 34  Multiple endocrine neoplasia-type 1 (MEN1) is ...
# 35  Multiple endocrine neoplasia-type 1 (MEN1) is ...
# 36  Background: Deficiencies in membrane polyunsat...
# 37  Background: Deficiencies in membrane polyunsat...
# 38  Background: Deficiencies in membrane polyunsat...
# 39  Background: Deficiencies in membrane polyunsat...
# 40  Background: Deficiencies in membrane polyunsat...
# 41  Background: Deficiencies in membrane polyunsat...
# 42  Background: Deficiencies in membrane polyunsat...
# 43  Background: Deficiencies in membrane polyunsat...
# 44  Background: Deficiencies in membrane polyunsat...
# 45  Background: Deficiencies in membrane polyunsat...
# 46  Background: Deficiencies in membrane polyunsat...
# 47  Background: Deficiencies in membrane polyunsat...
# 48  Background: Deficiencies in membrane polyunsat...
# 49  Background: Deficiencies in membrane polyunsat...
#
#                                                    E1        Type_E1  \
# 0                     Transforming growth factor beta          CHEBI
# 1                     Transforming growth factor beta          CHEBI
# 2                     Transforming growth factor beta          CHEBI
# 3                     Transforming growth factor beta          CHEBI
# 4                     Transforming growth factor beta          CHEBI
# 5                                                BMPs       CHEMICAL
# 6                preserved vitamin E levels?Vitamin E          CHEBI
# 7                                 metabolic disorders        DISEASE
# 8                                 metabolic disorders        DISEASE
# 9                                 metabolic disorders        DISEASE
# 10                                metabolic disorders        DISEASE
# 11                                thiamine deficiency          CHEBI
# 12                                Thiamine deficiency          CHEBI
# 13                                Thiamine deficiency          CHEBI
# 14                                Thiamine deficiency          CHEBI
# 15                                Thiamine deficiency          CHEBI
# 16                                Thiamine deficiency          CHEBI
# 17                                Thiamine deficiency          CHEBI
# 18                                Thiamine deficiency          CHEBI
# 19                           thiamine supplementation          CHEBI
# 20                                 vitamin deficiency          CHEBI
# 21                                 Bipolar depression  MENTAL_HEALTH
# 22                                 bipolar depression  MENTAL_HEALTH
# 23                                          dizziness        DISEASE
# 24                                          tiredness        DISEASE
# 25                      typical cannabis side effects       CHEMICAL
# 26                                                TRD        DISEASE
# 27                     Treatment-resistant depression  MENTAL_HEALTH
# 28                                         TH deficit       CHEMICAL
# 29                                          Buspirone       CHEMICAL
# 30                                          Buspirone       CHEMICAL
# 31                  Multiple endocrine neoplasia-type          CHEBI
# 32                  Multiple endocrine neoplasia-type          CHEBI
# 33                  Multiple endocrine neoplasia-type          CHEBI
# 34                          growing pituitary adenoma        DISEASE
# 35                          growing pituitary adenoma        DISEASE
# 36                                          n-3 index       CHEMICAL
# 37                                          n-3 index       CHEMICAL
# 38                                          n-3 index       CHEMICAL
# 39                                         PUFA ratio       CHEMICAL
# 40                                       n-3 PUFA DHA       CHEMICAL
# 41                                       n-3 PUFA DHA       CHEMICAL
# 42                                                EPA       CHEMICAL
# 43                                      Nervonic acid       CHEMICAL
# 44                                      Nervonic acid       CHEMICAL
# 45                         monounsaturated fatty acid      NUTRITION
# 46                         monounsaturated fatty acid      NUTRITION
# 47  long-chain saturated fatty acid tetracosanoic ...      NUTRITION
# 48  long-chain saturated fatty acid tetracosanoic ...      NUTRITION
# 49                                              mania  MENTAL_HEALTH
#
#                                              Relation  \
# 0                                  be dysregulated in
# 1                                  be dysregulated in
# 2                                  be dysregulated in
# 3                                  be dysregulated in
# 4                                  be dysregulated in
# 5                     have signaling abnormalities in
# 6                                         be added to
# 7                                  be associated with
# 8                                  be associated with
# 9                                  be associated with
# 10                                 be associated with
# 11                                   be associated in
# 12                            contribute to number of
# 13                            contribute to number of
# 14                            contribute to number of
# 15                            contribute to number of
# 16                            contribute to number of
# 17                            contribute to number of
# 18                            contribute to number of
# 19             have the putative beneficial effect in
# 20                                     have a case of
# 21                              have poor response to
# 22                                        be based on
# 23                                         occur with
# 24                                         occur with
# 25                                         occur with
# 26  be characterized by failure of adequate trial ...
# 27  be characterized by failure of adequate trial ...
# 28                                            trigger
# 29  seem to effective as benzodiazepines in allevi...
# 30                               seem to effective as
# 31                                   characterized by
# 32                                   characterized by
# 33                                   characterized by
# 34  cause during follow-up acromegaly with elevate...
# 35                                       cause during
# 36                         correlate with severity of
# 37                         correlate with severity of
# 38                         correlate with severity of
# 39                         correlate with severity of
# 40                         correlate with severity of
# 41                         correlate with severity of
# 42                                     correlate with
# 43                                     correlate with
# 44                                     correlate with
# 45                                     correlate with
# 46                                     correlate with
# 47                                     correlate with
# 48                                     correlate with
# 49              be associated with several classes of
#
#                                                    E2        Type_E2
# 0                                subcortical infarcts        DISEASE
# 1                        cerebral autosomal recessive        DISEASE
# 2                                      hereditary SVD        DISEASE
# 3                              recessive arteriopathy        DISEASE
# 4                                 leukoencephalopathy        DISEASE
# 5                                        sporadic SVD        DISEASE
# 6                             rancherosSome vitamin E          CHEBI
# 7         respiratory chain)Maple syrup urine disease       CHEMICAL
# 8         respiratory chain)Maple syrup urine disease        DISEASE
# 9                                                MSUD        DISEASE
# 10  low carnitine levels?Organic acidaemiasFatty a...       CHEMICAL
# 11                                       malnutrition        DISEASE
# 12                                              death        DISEASE
# 13                                 sleep disturbances        DISEASE
# 14                                             ataxia        DISEASE
# 15                           congestive heart failure        DISEASE
# 16                                          confusion        DISEASE
# 17                                     muscle atrophy        DISEASE
# 18                              severe encephalopathy        DISEASE
# 19                           autism spectrum disorder  MENTAL_HEALTH
# 20                           autism spectrum disorder  MENTAL_HEALTH
# 21                          antidepressant medication       CHEMICAL
# 22                                    antidepressants       CHEMICAL
# 23                                 cannabis medicines       CHEMICAL
# 24                                 cannabis medicines       CHEMICAL
# 25                                 cannabis medicines       CHEMICAL
# 26                                     antidepressant       CHEMICAL
# 27                                     antidepressant       CHEMICAL
# 28                            functional deficiencies        DISEASE
# 29                                            anxiety  MENTAL_HEALTH
# 30                                    benzodiazepines       CHEMICAL
# 31                            parathyroid hyperplasia        DISEASE
# 32                       pancreatic endocrine tumours          CHEBI
# 33                                 pituitary adenomas        DISEASE
# 34                                     growth hormone          CHEBI
# 35                               follow-up acromegaly        DISEASE
# 36                                     manic symptoms        DISEASE
# 37                                 psychotic symptoms        DISEASE
# 38                                depressive symptoms        DISEASE
# 39                                 psychotic symptoms        DISEASE
# 40                                  positive symptoms        DISEASE
# 41                                              manic        DISEASE
# 42                                     manic symptoms        DISEASE
# 43                                     manic symptoms        DISEASE
# 44                                depressive symptoms        DISEASE
# 45                                     manic symptoms        DISEASE
# 46                                depressive symptoms        DISEASE
# 47                                  positive symptoms        DISEASE
# 48                                              manic        DISEASE
# 49                                                FAs       CHEMICAL

# %%
def get_full_words(abbr:str, abstract:str, nlp)->str:
    """
    Get full words of a given abbreviation in sentence
    """
    # Find spans that contains abbreviation
    doc = nlp(abstract)
    abbr_phrase = None
    for sent in doc.sents:
      find_abbr = re.compile(f"(.+) (\(|\[){abbr}(\)|\])").findall(sent.text)
      if len(find_abbr) > 0:
        abbr_phrase = find_abbr[0][0]
    if not abbr_phrase:
      return abbr

    abbr_phrase = nlp(abbr_phrase)
    full_words = []
    i = len(abbr_phrase) - 1
    while i >= 0:
      if abbr_phrase[i].pos_ not in ['ADJ', 'NOUN', 'PROPN', 'PART', 'NUM']:
        break
      full_words.append(abbr_phrase[i].text)
      i -= 1

    return ' '.join(full_words[::-1]).strip()

# %%
abbr_dict = {}
full_df = full_df.reset_index(drop=True)
# changes all abbreviations in dataframe to their full words
## Use get_full_words
print("Using get_full_words function:")
full_df['Full_E1'] = full_df['E1'].tolist()
full_df['Full_E2'] = full_df['E2'].tolist()

for idx, row in full_df.iterrows():
    abstract = row['Abstract']

    if idx%100 == 0:
      print(f"Row {idx}")
    
    # Full words of E1
    e1 = re.sub(r"total |further |other |many |much |several |some ", "", str(row['E1']))
    try:
      full_e1 = get_full_words(abbr=e1, abstract=abstract, nlp=gena_nlp)
      if e1 != full_e1:
        abbr_dict[e1] = full_e1
      full_df.loc[idx, "E1"] = e1
      full_df.loc[idx, "Full_E1"] = full_e1
    except:
      print(e1)


    # Full words of E2
    e2 = re.sub(r"total |further |other |many |much |several |some ", "", str(row['E2']))
    try:
      full_e2 = get_full_words(abbr=e2, abstract=abstract, nlp=gena_nlp)
      if e2 != full_e2:
        abbr_dict[e2] = full_e2
      full_df.loc[idx, "E2"] = e2
      full_df.loc[idx, "Full_E2"] = full_e2
    except:
      print(e2)

## Use dictionary
# print("Using abbreviation dictionary:")
# for idx, row in full_df.iterrows():
#     e1 = row['E1']
#     e2 = row['E2']

#     if idx%100 == 0:
#         print(f"Row {idx}")
    
#     full_df.loc[idx, 'E1'] = abbr_dict.get(e1, e1)
#     full_df.loc[idx, 'E2'] = abbr_dict.get(e2, e2)

# # Save to file csv
# full_df = full_df.drop_duplicates(keep='first')
# full_df.to_csv("nah_normalize.csv", index=False)

# Numbers of relation
# print(f"There are {len(full_df)} relations now.")
abbr_dict.items()
# Out:
# Using get_full_words function:
# Row 0
# respiratory chain)Maple syrup urine disease
# respiratory chain)Maple syrup urine disease
# Row 100
# Row 200
# Row 300
# Row 400
# receptor A(HTR1 A
# 5-HT(1B/1D/1F receptor agonist
# Row 500
# FU(OX
# Row 600
# Row 700
# g. (+)-alpha-pinene
# Row 800
# selective 5-HT(2A receptor antagonist eplivanserin
# selective 5-HT(2A receptor antagonist eplivanserin
# nonselective serotonin 5-HT(2A/2C receptor antagonists
# nonselective serotonin 5-HT(2A/2C receptor antagonists
# 5-HT(2A receptor
# 5-HT(2A receptor
# Row 900
# 5-HT(2A receptor antagonist
# 5-HT(2A receptor antagonist
# Row 1000
# specific L-(3H glutamate binding
# L-(3H glutamate
# Row 1100
# Row 1200
# Row 1300
# (+)-9'-allyl-ABA
# (+)-9'-allyl-ABA
# Polyglutamine Binding Peptide-1(QBP1
# Row 1400
# CB(2 receptors
# CB(2 receptor agonists
# CB(2 receptor agonists
# Row 1500
# cm(3
# Row 1600
# Row 1700
# Row 1800
# Row 1900
# Row 2000
# Row 2100
# Cl(-
# F(-
# Row 2200
# Row 2300
# [D-Arg]-SP
# [D-Arg]-SP
# Row 2400
# Row 2500
# (±)-N-methyl-γ-[4-(trifluoromethyl)phenoxy]benzenepropanamine hydrochloride
# 5H(+
# Row 2600
# poly(HAMAm-b-HEPOMAn
# Row 2700
# Row 2800
# Row 2900
# Row 3000
# Row 3100
# 5-HT(1A receptor agonist
# 5-HT(1A receptor agonist
# 5-HT(1A receptor agonist
# 5-HT(1A receptor agonist
# GABA(A receptor antagonists
# GABA(A receptor antagonists
# GABA(A receptor antagonists
# GABA(A receptor antagonists
# Row 3200
# Row 3300
# Row 3400
# Row 3500
# SR)-i-Bu HCl crystal structure
# Paroxetine stabilizer(s
# Row 3600
# Row 3700
# Row 3800
# Row 3900
# Row 4000
# Row 4100
# Row 4200
# E(2)(7
# Row 4300
# Row 4400
# Row 4500
# Row 4600
# Row 4700
# Row 4800
# lactate clearance(LC
# Row 4900
# Row 5000
# Row 5100
# Row 5200
# ATP MgSO(4
# CO(2 fixation
# dark (14)CO(2 fixation
# dark (14)CO(2 fixation
# dark (14)CO(2 fixation periods
# (14)CO(2 fixation products
# (14)CO(2 fixation products
# dark CO(2 fixation
# dark CO(2 fixation
# dark CO(2 fixation
# Row 5300
# 0.0004).CONCLUSIONSPropranolol
# Row 5400
# ml CO2 h(-1
# ml CO2 h(-1
# H2O h(-1
# 5-HT(2C receptor agonist
# 5-HT(2C receptor agonist
# 5-HT(1A antagonist
# 5-HT(1A antagonist
# Row 5500
# Row 5600
# Row 5700
# Row 5800
# Row 5900
# Row 6000
# Row 6100
# effective 5-HT(1B/1D agonists
# effective 5-HT(1B/1D agonists
# effective 5-HT(1B/1D agonists
# effective 5-HT(1B/1D agonists
# Row 6200
# effective 5-HT(1B/1D agonists
# effective 5-HT(1B/1D agonists
# Row 6300
# (+)HA-966
# (+)HA-966
# (+)HA-966
# (+)HA-966
# Row 6400
# Row 6500
# Row 6600
# alpha(2C antagonist rauwolscine
# Row 6700
# alpha(2C antagonist rauwolscine
# mmol g(-1
# 0.48+/-0.037 mmol g(-1
# Row 6800
# Row 6900
# Row 7000
# Row 7100
# Row 7200
# Row 7300
# Row 7400
# Row 7500
# Row 7600
# Row 7700
# Row 7800
# Row 7900
# Row 8000
# Row 8100
# Row 8200
# Row 8300
# CC HCVAb(+
# CC HCVAb(+
# LPC(L-a-lysophosphatidylcholine
# Row 8400
# vitamin B(12 deficiency
# vitamin B(12 deficiency
# Row 8500
# Row 8600
# dict_items([('BMPs', 'bone morphogenetic proteins'), ('MSUD', 'maple syrup urine disease'), ('TRD', 'Treatment-resistant depression'), ('EPA', 'eicosapentaenoic acid'), ('NICCD', 'neonatal intrahepatic cholestasis'), ('CTLN2', 'adult-onset type II citrullinemia'), ('ASD', 'Autism Spectrum Disorder'), ('LT3', 'liothyronine'), ('COVID-19', '2019 novel coronavirus disease'), ('phenolic compounds', 'Alkylresorcinol'), ('ADP', 'Accidental dural puncture'), ('TB', 'tuberculosis'), ('EHA', 'Egg Hatch Assay'), ('VRD', 'NMDA-induced ventral root depolarization'), ('MPEP', 'pyridine'), ('ADHD', 'Attention-deficit/hyperactivity disorder'), ('LC-PUFA', 'omega-6 long-chain PUFA'), ('SRS', 'less smoking-related symptomatology'), ('CP', 'aphasia'), ('TTP', 'μg/day transdermal testosterone patch'), ('HSDD', 'hypoactive sexual desire disorder'), ('PS', 'paradoxical sleep'), ('AA', 'more arachidonic acid'), ('MDD', 'major depressive disorder'), ('long-acting dihydropyridine', 'nisoldipine'), ('nano-Se', ''), ('Nano-Se', 'Nano‑selenium'), ('CRF', 'Corticotropin-Releasing Factor'), ('GABA', 'gamma-aminobutyric acid'), ('PPA', 'Propionic acid'), ('CUD', 'Cannabis Use Disorder'), ('5-HIAA', '5-hydroxyindole acetic acid'), ('5-HT', 'related to 5-hydroxytriptamine'), ('OCD', 'obsessive-compulsive disorder'), ('TBI', 'traumatic brain injury'), ('PWS', 'Prader-Willi syndrome'), ('ABA', 'abscisic acid'), ('triiodiothyronine', 'liothyronine'), ('ADT', 'androgen deprivation therapy'), ('AIDS', 'immunodeficiency syndrome'), ('6-OHDA', '6-hydroxydopamine'), ('MPTP', '1-methyl-4-phenyl-1,2,3,6-tetrahydropyridine'), ('Mentha spicata L.', 'Spearmint'), ('Linum usitatissimum L.', 'flaxseed'), ('VPA', 'valproic acid'), ('CBZ', 'carbamazepine'), ('DS-ALL', 'Down syndrome-associated acute lymphoblastic leukemia'), ('PCOS', 'polycystic ovary syndrome'), ('Cr', 'phosphocreatine'), ('Hg', 'mercury'), ('LQTS', 'congenital long QT syndrome'), ('Japanese pine sawyer', 'Monochamus alternatus'), ('gut dysbiosis', 'gut microbiota dysbiosis'), ('OSAS', 'Obstructive sleep apnea syndrome'), ('apomorphine', 'dopamine agonist'), ('PD', "Parkinson 's disease"), ('TOAD', 'Auditory Discrimination'), ('LI', 'latent inhibition'), ('LPS', 'lipopolysaccharide'), ('GSK3β', 'glycogen synthase kinase 3β'), ('alpha-methl-p-tyrosine', 'catecholamine synthesis inhibitors'), ('TCA', 'taurocholic acid'), ('NE', 'Neutrophil elastase'), ('HTN', 'hypertension'), ('Muscimol', 'GABA-agonist'), ('MUFA', 'monounsaturated fatty acids'), ('SNRI', 'serotonin-norepinephrine reuptake inhibitor'), ('AD-MD', "Alzheimer 's disease"), ('METH', 'Methamphetamine'), ('SB-tPS', 'Soybean lecithin transphosphatidylated phosphatidylserine'), ('BC-PS', 'bovine brain cortex-derived phosphatidylserine'), ('TCAs', 'tricyclic antidepressants'), ('HFS', 'high frequencies'), ('≤13 years', 'aerial photographs'), ('LAUP', 'Laser-assisted uvulopalatoplasty'), ('RVVC', 'recurrent vulvovaginal candidiasis'), ('PMS', 'premenstrual syndrome'), ('GPC-3', 'glypican-3 gene'), ('SWS', 'light slow-wave sleep'), ('NLX', 'naloxone'), ('TCDD', '2,3,7,8-tetrachlorodibenzo-p-dioxin'), ('Kyn', 'kynurenine'), ('GSH', 'serum glutathione'), ('GSSG', 'glutathione disulfide'), ('GSNO', 'S-nitrosoglutathione'), ('hypoxia', 'O2'), ('WKS', "Wernicke-Korsakoff 's syndrome"), ('AUD', 'alcohol use disorder'), ('SGAs', 'second-generation antipsychotics'), ('SSRI', 'serotonin reuptake inhibitors'), ('PG', 'Pathological gambling'), ('trichotillomania', 'hair-pulling'), ('pyromania', 'fires'), ('PUFA', 'polyunsaturated fatty acids'), ('HT', 'Hormone therapy'), ('mCPP', 'not'), ('PPH', 'primary pulmonary hypertension'), ('GD', 'Gaucher disease'), ('IPA', 'Invasive pulmonary aspergillosis'), ('CIH', 'chronic intermittent hypoxia'), ('OSAHS', 'Obstructive sleep apnea hypopnea syndrome'), ('SSRIs', 'selective serotonin reuptake inhibitors'), ('endoCBs', 'endocannabinoids'), ('ARDS', 'acute respiratory distress syndrome'), ('Ng', 'gonorrhoeae'), ('ESRD', 'end ...

# %%
# !pip install periodictable
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting periodictable
#   Downloading periodictable-1.6.1-py2.py3-none-any.whl (752 kB)
#      |████████████████████████████████| 752 kB 5.1 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from periodictable) (1.21.6)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from periodictable) (3.0.9)
# Installing collected packages: periodictable
# Successfully installed periodictable-1.6.1

# %%
import periodictable
## Use dictionary and periodictable
print("Using abbreviation dictionary:")
for idx, row in full_df.iterrows():
    if idx%100 == 0:
        print(f"Row {idx}")    
    e1 = row['E1']
    e2 = row['E2']

    # Use dictionary
    full_df.loc[idx, 'Full_E1'] = abbr_dict.get(e1, e1)
    full_df.loc[idx, 'Full_E2'] = abbr_dict.get(e2, e2)

    # Use periodictable
    letters_1 = re.compile(r'([A-Za-z]+)').findall(e1)
    if len(letters_1) == 1:
      for el in periodictable.elements:
        if letters_1[0] == el.symbol:
            full_df.loc[idx, 'Full_E1'] = el.name
    
    letters_2 = re.compile(r'([A-Za-z]+)').findall(e2)
    if len(letters_2) == 1:
      for el in periodictable.elements:
        if letters_2[0] == el.symbol:
            full_df.loc[idx, 'Full_E2'] = el.name
# Out:
# Using abbreviation dictionary:
# Row 0
# Row 100
# Row 200
# Row 300
# Row 400
# Row 500
# Row 600
# Row 700
# Row 800
# Row 900
# Row 1000
# Row 1100
# Row 1200
# Row 1300
# Row 1400
# Row 1500
# Row 1600
# Row 1700
# Row 1800
# Row 1900
# Row 2000
# Row 2100
# Row 2200
# Row 2300
# Row 2400
# Row 2500
# Row 2600
# Row 2700
# Row 2800
# Row 2900
# Row 3000
# Row 3100
# Row 3200
# Row 3300
# Row 3400
# Row 3500
# Row 3600
# Row 3700
# Row 3800
# Row 3900
# Row 4000
# Row 4100
# Row 4200
# Row 4300
# Row 4400
# Row 4500
# Row 4600
# Row 4700
# Row 4800
# Row 4900
# Row 5000
# Row 5100
# Row 5200
# Row 5300
# Row 5400
# Row 5500
# Row 5600
# Row 5700
# Row 5800
# Row 5900
# Row 6000
# Row 6100
# Row 6200
# Row 6300
# Row 6400
# Row 6500
# Row 6600
# Row 6700
# Row 6800
# Row 6900
# Row 7000
# Row 7100
# Row 7200
# Row 7300
# Row 7400
# Row 7500
# Row 7600
# Row 7700
# Row 7800
# Row 7900
# Row 8000
# Row 8100
# Row 8200
# Row 8300
# Row 8400
# Row 8500
# Row 8600

# %%
print(len(full_df))
full_df = full_df.drop_duplicates(subset=['Full_E1', 'Relation', 'Full_E2']).reset_index(drop=True)
print(len(full_df))
# Out:
# 8692
# 7896

# %%
full_df.to_csv("gena_data_normalized_3.csv", index=False)

# %% [markdown]
# # Get ID for all Entities from MeSH

# %%
# Get new relations extracted
import pandas as pd
gena_normal = pd.read_csv("gena_data_normalized_3.csv")
gena_normal_relation = gena_normal[["PMID", "Sentence", "E1", "Type_E1", "Relation", "E2", "Type_E2", "Full_E1", "Full_E2"]]
gena_normal_relation["ID_1"] = [""]*len(gena_normal_relation)
gena_normal_relation["ID_2"] = [""]*len(gena_normal_relation)
gena_normal_relation["Synonyms_1"] = [""]*len(gena_normal_relation)
gena_normal_relation["Synonyms_2"] = [""]*len(gena_normal_relation)
gena_normal_relation = gena_normal_relation[["PMID", "Sentence", "ID_1", "E1", "Type_E1", "Full_E1", "Synonyms_1", "Relation", "ID_2", "E2", "Type_E2", "Full_E2", "Synonyms_2"]]

gena_normal_relation.head(5)
# Out:
#        PMID                                           Sentence ID_1  \
# 0  28470822  Transforming growth factor beta 1 (TGFB1) is d...
# 1  28470822  Transforming growth factor beta 1 (TGFB1) is d...
# 2  28470822  Transforming growth factor beta 1 (TGFB1) is d...
# 3  28470822  Transforming growth factor beta 1 (TGFB1) is d...
# 4  28470822  Transforming growth factor beta 1 (TGFB1) is d...
#
#                                 E1 Type_E1                          Full_E1  \
# 0  Transforming growth factor beta   CHEBI  Transforming growth factor beta
# 1  Transforming growth factor beta   CHEBI  Transforming growth factor beta
# 2  Transforming growth factor beta   CHEBI  Transforming growth factor beta
# 3  Transforming growth factor beta   CHEBI  Transforming growth factor beta
# 4  Transforming growth factor beta   CHEBI  Transforming growth factor beta
#
#   Synonyms_1            Relation ID_2                            E2  Type_E2  \
# 0             be dysregulated in               subcortical infarcts  DISEASE
# 1             be dysregulated in       cerebral autosomal recessive  DISEASE
# 2             be dysregulated in                     hereditary SVD  DISEASE
# 3             be dysregulated in             recessive arteriopathy  DISEASE
# 4             be dysregulated in                leukoencephalopathy  DISEASE
#
#                         Full_E2 Synonyms_2
# 0          subcortical infarcts
# 1  cerebral autosomal recessive
# 2                hereditary SVD
# 3        recessive arteriopathy
# 4           leukoencephalopathy

# %%
def find_mesh_info(term:str)->tuple:
    """
    Get MeSH info (ID, Title and Synonyms) of a given term
    """
    root_URL = "https://www.ncbi.nlm.nih.gov"
    URL = f"{root_URL}/mesh/?term=\"{term}\"+%5BText+Words%5D"
    results = BeautifulSoup(requests.get(URL).content, "html.parser")
    first_result = results.find("div", class_="rslt")
    if first_result:
        detailed_URL = root_URL + first_result.find("a")['href']
        results = BeautifulSoup(requests.get(detailed_URL).content, "html.parser")
    elif results.find("span", class_="icon", string="No items found."):
        return ("No_ID_MeSH", term, "No synonyms")

    title = results.find("h1", class_="title").text
    mesh_id = results.find("p", text=re.compile(r'MeSH Unique ID.*')).text.replace("MeSH Unique ID: ", "")
    results_ab = results.find("div", class_="rprt abstract")
    mesh_synonyms = results_ab.findChildren("ul", recursive=False)
    if len(mesh_synonyms) > 0:
        all_synonyms = [syn.text for syn in BeautifulSoup(str(mesh_synonyms[0]), "html.parser").find_all("li")]
        return (mesh_id, title, '|'.join(all_synonyms))
    else:
        return (mesh_id, title, "No synonyms")

# %%
term ="meropenem"
term_lemma = ' '.join([token.lemma_ for token in gena_nlp(term)])
find_mesh_info(term_lemma)
# Out:
# ('D000077731',
#  'Meropenem',
#  '3-(5-Dimethylcarbamoylpyrrolidin-3-ylthio)-6-(1-hydroxyethyl)-4-methyl-7-oxo-1-azabicyclo(3.2.0)hept-2-ene-2-carboxylic acid|Merrem|Ronem|Penem|SM 7338|SM-7338|SM7338')

# %%
gena_normal_relation.head(5)
# Out:
#        PMID                                           Sentence ID_1  \
# 0  28470822  Transforming growth factor beta 1 (TGFB1) is d...
# 1  28470822  Transforming growth factor beta 1 (TGFB1) is d...
# 2  28470822  Transforming growth factor beta 1 (TGFB1) is d...
# 3  28470822  Transforming growth factor beta 1 (TGFB1) is d...
# 4  28470822  Transforming growth factor beta 1 (TGFB1) is d...
#
#                                 E1 Type_E1                          Full_E1  \
# 0  Transforming growth factor beta   CHEBI  Transforming growth factor beta
# 1  Transforming growth factor beta   CHEBI  Transforming growth factor beta
# 2  Transforming growth factor beta   CHEBI  Transforming growth factor beta
# 3  Transforming growth factor beta   CHEBI  Transforming growth factor beta
# 4  Transforming growth factor beta   CHEBI  Transforming growth factor beta
#
#   Synonyms_1            Relation ID_2                            E2  Type_E2  \
# 0             be dysregulated in               subcortical infarcts  DISEASE
# 1             be dysregulated in       cerebral autosomal recessive  DISEASE
# 2             be dysregulated in                     hereditary SVD  DISEASE
# 3             be dysregulated in             recessive arteriopathy  DISEASE
# 4             be dysregulated in                leukoencephalopathy  DISEASE
#
#                         Full_E2 Synonyms_2
# 0          subcortical infarcts
# 1  cerebral autosomal recessive
# 2                hereditary SVD
# 3        recessive arteriopathy
# 4           leukoencephalopathy

# %%
from time import sleep
gena_normal_relation['MeSH_E1'] = ['']*len(gena_normal_relation)
gena_normal_relation['MeSH_E2'] = ['']*len(gena_normal_relation)

mesh_dict = {}

for idx, row in gena_normal_relation.iterrows():
    print(idx)
    if idx < 7759:
      continue
    if not mesh_dict.get(str(row['Full_E1']), False):
      try:
        mesh_results_1 = find_mesh_info(str(row['Full_E1']))
        sleep(2)
      except:
        sleep(120)
        mesh_results_1 = find_mesh_info(str(row['Full_E1']))
        sleep(2)
      mesh_dict[str(row['Full_E1'])] = mesh_results_1

    if not mesh_dict.get(str(row['Full_E2']), False):
      try:
        mesh_results_2 = find_mesh_info(str(row['Full_E2']))
        sleep(2)
      except:
        sleep(120)
        mesh_results_2 = find_mesh_info(str(row['Full_E2']))
        sleep(2)
      mesh_dict[str(row['Full_E2'])] = mesh_results_2
    
    # Fill into the dataframe
    # Entities 1
    gena_normal_relation.loc[idx, 'ID_1'] = mesh_dict[str(row['Full_E1'])][0]
    gena_normal_relation.loc[idx, 'MeSH_E1'] = mesh_dict[str(row['Full_E1'])][1]
    gena_normal_relation.loc[idx, 'Synonyms_1'] = mesh_dict[str(row['Full_E1'])][2]
    
    # Entities 2
    gena_normal_relation.loc[idx, 'ID_2'] = mesh_dict[str(row['Full_E2'])][0]
    gena_normal_relation.loc[idx, 'MeSH_E2'] = mesh_dict[str(row['Full_E2'])][1]
    gena_normal_relation.loc[idx, 'Synonyms_2'] = mesh_dict[str(row['Full_E2'])][2]
# Out:
# Streaming output truncated to the last 5000 lines.
# 2896
# 2897
# 2898
# 2899
# 2900
# 2901
# 2902
# 2903
# 2904
# 2905
# 2906
# 2907
# 2908
# 2909
# 2910
# 2911
# 2912
# 2913
# 2914
# 2915
# 2916
# 2917
# 2918
# 2919
# 2920
# 2921
# 2922
# 2923
# 2924
# 2925
# 2926
# 2927
# 2928
# 2929
# 2930
# 2931
# 2932
# 2933
# 2934
# 2935
# 2936
# 2937
# 2938
# 2939
# 2940
# 2941
# 2942
# 2943
# 2944
# 2945
# 2946
# 2947
# 2948
# 2949
# 2950
# 2951
# 2952
# 2953
# 2954
# 2955
# 2956
# 2957
# 2958
# 2959
# 2960
# 2961
# 2962
# 2963
# 2964
# 2965
# 2966
# 2967
# 2968
# 2969
# 2970
# 2971
# 2972
# 2973
# 2974
# 2975
# 2976
# 2977
# 2978
# 2979
# 2980
# 2981
# 2982
# 2983
# 2984
# 2985
# 2986
# 2987
# 2988
# 2989
# 2990
# 2991
# 2992
# 2993
# 2994
# 2995
# 2996
# 2997
# 2998
# 2999
# 3000
# 3001
# 3002
# 3003
# 3004
# 3005
# 3006
# 3007
# 3008
# 3009
# 3010
# 3011
# 3012
# 3013
# 3014
# 3015
# 3016
# 3017
# 3018
# 3019
# 3020
# 3021
# 3022
# 3023
# 3024
# 3025
# 3026
# 3027
# 3028
# 3029
# 3030
# 3031
# 3032
# 3033
# 3034
# 3035
# 3036
# 3037
# 3038
# 3039
# 3040
# 3041
# 3042
# 3043
# 3044
# 3045
# 3046
# 3047
# 3048
# 3049
# 3050
# 3051
# 3052
# 3053
# 3054
# 3055
# 3056
# 3057
# 3058
# 3059
# 3060
# 3061
# 3062
# 3063
# 3064
# 3065
# 3066
# 3067
# 3068
# 3069
# 3070
# 3071
# 3072
# 3073
# 3074
# 3075
# 3076
# 3077
# 3078
# 3079
# 3080
# 3081
# 3082
# 3083
# 3084
# 3085
# 3086
# 3087
# 3088
# 3089
# 3090
# 3091
# 3092
# 3093
# 3094
# 3095
# 3096
# 3097
# 3098
# 3099
# 3100
# 3101
# 3102
# 3103
# 3104
# 3105
# 3106
# 3107
# 3108
# 3109
# 3110
# 3111
# 3112
# 3113
# 3114
# 3115
# 3116
# 3117
# 3118
# 3119
# 3120
# 3121
# 3122
# 3123
# 3124
# 3125
# 3126
# 3127
# 3128
# 3129
# 3130
# 3131
# 3132
# 3133
# 3134
# 3135
# 3136
# 3137
# 3138
# 3139
# 3140
# 3141
# 3142
# 3143
# 3144
# 3145
# 3146
# 3147
# 3148
# 3149
# 3150
# 3151
# 3152
# 3153
# 3154
# 3155
# 3156
# 3157
# 3158
# 3159
# 3160
# 3161
# 3162
# 3163
# 3164
# 3165
# 3166
# 3167
# 3168
# 3169
# 3170
# 3171
# 3172
# 3173
# 3174
# 3175
# 3176
# 3177
# 3178
# 3179
# 3180
# 3181
# 3182
# 3183
# 3184
# 3185
# 3186
# 3187
# 3188
# 3189
# 3190
# 3191
# 3192
# 3193
# 3194
# 3195
# 3196
# 3197
# 3198
# 3199
# 3200
# 3201
# 3202
# 3203
# 3204
# 3205
# 3206
# 3207
# 3208
# 3209
# 3210
# 3211
# 3212
# 3213
# 3214
# 3215
# 3216
# 3217
# 3218
# 3219
# 3220
# 3221
# 3222
# 3223
# 3224
# 3225
# 3226
# 3227
# 3228
# 3229
# 3230
# 3231
# 3232
# 3233
# 3234
# 3235
# 3236
# 3237
# 3238
# 3239
# 3240
# 3241
# 3242
# 3243
# 3244
# 3245
# 3246
# 3247
# 3248
# 3249
# 3250
# 3251
# 3252
# 3253
# 3254
# 3255
# 3256
# 3257
# 3258
# 3259
# 3260
# 3261
# 3262
# 3263
# 3264
# 3265
# 3266
# 3267
# 3268
# 3269
# 3270
# 3271
# 3272
# 3273
# 3274
# 3275
# 3276
# 3277
# 3278
# 3279
# 3280
# 3281
# 3282
# 3283
# 3284
# 3285
# 3286
# 3287
# 3288
# 3289
# 3290
# 3291
# 3292
# 3293
# 3294
# 3295
# 3296
# 3297
# 3298
# 3299
# 3300
# 3301
# 3302
# 3303
# 3304
# 3305
# 3306
# 3307
# 3308
# 3309
# 3310
# 3311
# 3312
# 3313
# 3314
# 3315
# 3316
# 3317
# 3318
# 3319
# 3320
# 3321
# 3322
# 3323
# 3324
# 3325
# 3326
# 3327
# 3328
# 3329
# 3330
# 3331
# 3332
# 3333
# 3334
# 3335
# 3336
# 3337
# 3338
# 3339
# 3340
# 3341
# 3342
# 3343
# 3344
# 3345
# 3346
# 3347
# 3348
# 3349
# 3350
# 3351
# 3352
# 3353
# 3354
# 3355
# 3356
# 3357
# 3358
# 3359
# 3360
# 3361
# 3362
# 3363
# 3364
# 3365
# 3366
# 3367
# 3368
# 3369
# 3370
# 3371
# 3372
# 3373
# 3374
# 3375
# 3376
# 3377
# 3378
# 3379
# 3380
# 3381
# 3382
# 3383
# 3384
# 3385
# 3386
# 3387
# 3388
# 3389
# 3390
# 3391
# 3392
# 3393
# 3394
# 3395
# 3396
# 3397
# 3398
# 3399
# 3400
# 3401
# 3402
# 3403
# 3404
# 3405
# 3406
# 3407
# 3408
# 3409
# 3410
# 3411
# 3412
# 3413
# 3414
# 3415
# 3416
# 3417
# 3418
# 3419
# 3420
# 3421
# 3422
# 3423
# 3424
# 3425
# 3426
# 3427
# 3428
# 3429
# 3430
# 3431
# 3432
# 3433
# 3434
# 3435
# 3436
# 3437
# 3438
# 3439
# 3440
# 3441
# 3442
# 3443
# 3444
# 3445
# 3446
# 3447
# 3448
# 3449
# 3450
# 3451
# 3452
# 3453
# 3454
# 3455
# 3456
# 3457
# 3458
# 3459
# 3460
# 3461
# 3462
# 3463
# 3464
# 3465
# 3466
# 3467
# 3468
# 3469
# 3470
# 3471
# 3472
# 3473
# 3474
# 3475
# 3476
# 3477
# 3478
# 3479
# 3480
# 3481
# 3482
# 3483
# 3484
# 3485
# 3486
# 3487
# 3488
# 3489
# 3490
# 3491
# 3492
# 3493
# 3494
# 3495
# 3496
# 3497
# 3498
# 3499
# 3500
# 3501
# 3502
# 3503
# 3504
# 3505
# 3506
# 3507
# 3508
# 3509
# 3510
# 3511
# 3512
# 3513
# 3514
# 3515
# 3516
# 3517
# 3518
# 3519
# 3520
# 3521
# 3522
# 3523
# 3524
# 3525
# 3526
# 3527
# 3528
# 3529
# 3530
# 3531
# 3532
# 3533
# 3534
# 3535
# 3536
# 3537
# 3538
# 3539
# 3540
# 3541
# 3542
# 3543
# 3544
# 3545
# 3546
# 3547
# 3548
# 3549
# 3550
# 3551
# 3552
# 3553
# 3554
# 3555
# 3556
# 3557
# 3558
# 3559
# 3560
# 3561
# 3562
# 3563
# 3564
# 3565
# 3566
# 3567
# 3568
# 3569
# 3570
# 3571
# 3572
# 3573
# 3574
# 3575
# 3576
# 3577
# 3578
# 3579
# 3580
# 3581
# 3582
# 3583
# 3584
# 3585
# 3586
# 3587
# 3588
# 3589
# 3590
# 3591
# 3592
# 3593
# 3594
# 3595
# 3596
# 3597
# 3598
# 3599
# 3600
# 3601
# 3602
# 3603
# 3604
# 3605
# 3606
# 3607
# 3608
# 3609
# 3610
# 3611
# 3612
# 3613
# 3614
# 3615
# 3616
# 3617
# 3618
# 3619
# 3620
# 3621
# 3622
# 3623
# 3624
# 3625
# 3626
# 3627
# 3628
# 3629
# 3630
# 3631
# 3632
# 3633
# 3634
# 3635
# 3636
# 3637
# 3638
# 3639
# 3640
# 3641
# 3642
# 3643
# 3644
# 3645
# 3646
# 3647
# 3648
# 3649
# 3650
# 3651
# 3652
# 3653
# 3654
# 3655
# 3656
# 3657
# 3658
# 3659
# 3660
# 3661
# 3662
# 3663
# 3664
# 3665
# 3666
# 3667
# 3668
# 3669
# 3670
# 3671
# 3672
# 3673
# 3674
# 3675
# 3676
# 3677
# 3678
# 3679
# 3680
# 3681
# 3682
# 3683
# 3684
# 3685
# 3686
# 3687
# 3688
# 3689
# 3690
# 3691
# 3692
# 3693
# 3694
# 3695
# 3696
# 3697
# 3698
# 3699
# 3700
# 3701
# 3702
# 3703
# 3704
# 3705
# 3706
# 3707
# 3708
# 3709
# 3710
# 3711
# 3712
# 3713
# 3714
# 3715
# 3716
# 3717
# 3718
# 3719
# 3720
# 3721
# 3722
# 3723
# 3724
# 3725
# 3726
# 3727
# 3728
# 3729
# 3730
# 3731
# 3732
# 3733
# 3734
# 3735
# 3736
# 3737
# 3738
# 3739
# 3740
# 3741
# 3742
# 3743
# 3744
# 3745
# 3746
# 3747
# 3748
# 3749
# 3750
# 3751
# 3752
# 3753
# 3754
# 3755
# 3756
# 3757
# 3758
# 3759
# 3760
# 3761
# 3762
# 3763
# 3764
# 3765
# 3766
# 3767
# 3768
# 3769
# 3770
# 3771
# 3772
# 3773
# 3774
# 3775
# 3776
# 3777
# 3778
# 3779
# 3780
# 3781
# 3782
# 3783
# 3784
# 3785
# 3786
# 3787
# 3788
# 3789
# 3790
# 3791
# 3792
# 3793
# 3794
# 3795
# 3796
# 3797
# 3798
# 3799
# 3800
# 3801
# 3802
# 3803
# 3804
# 3805
# 3806
# 3807
# 3808
# 3809
# 3810
# 3811
# 3812
# 3813
# 3814
# 3815
# 3816
# 3817
# 3818
# 3819
# 3820
# 3821
# 3822
# 3823
# 3824
# 3825
# 3826
# 3827
# 3828
# 3829
# 3830
# 3831
# 3832
# 3833
# 3834
# 3835
# 3836
# 3837
# 3838
# 3839
# 3840
# 3841
# 3842
# 3843
# 3844
# 3845
# 3846
# 3847
# 3848
# 3849
# 3850
# 3851
# 3852
# 3853
# 3854
# 3855
# 3856
# 3857
# 3858
# 3859
# 3860
# 3861
# 3862
# 3863
# 3864
# 3865
# 3866
# 3867
# 3868
# 3869
# 3870
# 3871
# 3872
# 3873
# 3874
# 3875
# 3876
# 3877
# 3878
# 3879
# 3880
# 3881
# 3882
# 3883
# 3884
# 3885
# 3886
# 3887
# 3888
# 3889
# 3890
# 3891
# 3892
# 3893
# 3894
# 3895
# 3896
# 3897
# 3898
# 3899
# 3900
# 3901
# 3902
# 3903
# 3904
# 3905
# 3906
# 3907
# 3908
# 3909
# 3910
# 3911
# 3912
# 3913
# 3914
# 3915
# 3916
# 3917
# 3918
# 3919
# 3920
# 3921
# 3922
# 3923
# 3924
# 3925
# 3926
# 3927
# 3928
# 3929
# 3930
# 3931
# 3932
# 3933
# 3934
# 3935
# 3936
# 3937
# 3938
# 3939
# 3940
# 3941
# 3942
# 3943
# 3944
# 3945
# 3946
# 3947
# 3948
# 3949
# 3950
# 3951
# 3952
# 3953
# 3954
# 3955
# 3956
# 3957
# 3958
# 3959
# 3960
# 3961
# 3962
# 3963
# 3964
# 3965
# 3966
# 3967
# 3968
# 3969
# 3970
# 3971
# 3972
# 3973
# 3974
# 3975
# 3976
# 3977
# 3978
# 3979
# 3980
# 3981
# 3982
# 3983
# 3984
# 3985
# 3986
# 3987
# 3988
# 3989
# 3990
# 3991
# 3992
# 3993
# 3994
# 3995
# 3996
# 3997
# 3998
# 3999
# 4000
# 4001
# 4002
# 4003
# 4004
# 4005
# 4006
# 4007
# 4008
# 4009
# 4010
# 4011
# 4012
# 4013
# 4014
# 4015
# 4016
# 4017
# 4018
# 4019
# 4020
# 4021
# 4022
# 4023
# 4024
# 4025
# 4026
# 4027
# 4028
# 4029
# 4030
# 4031
# 4032
# 4033
# 4034
# 4035
# 4036
# 4037
# 4038
# 4039
# 4040
# 4041
# 4042
# 4043
# 4044
# 4045
# 4046
# 4047
# 4048
# 4049
# 4050
# 4051
# 4052
# 4053
# 4054
# 4055
# 4056
# 4057
# 4058
# 4059
# 4060
# 4061
# 4062
# 4063
# 4064
# 4065
# 4066
# 4067
# 4068
# 4069
# 4070
# 4071
# 4072
# 4073
# 4074
# 4075
# 4076
# 4077
# 4078
# 4079
# 4080
# 4081
# 4082
# 4083
# 4084
# 4085
# 4086
# 4087
# 4088
# 4089
# 4090
# 4091
# 4092
# 4093
# 4094
# 4095
# 4096
# 4097
# 4098
# 4099
# 4100
# 4101
# 4102
# 4103
# 4104
# 4105
# 4106
# 4107
# 4108
# 4109
# 4110
# 4111
# 4112
# 4113
# 4114
# 4115
# 4116
# 4117
# 4118
# 4119
# 4120
# 4121
# 4122
# 4123
# 4124
# 4125
# 4126
# 4127
# 4128
# 4129
# 4130
# 4131
# 4132
# 4133
# 4134
# 4135
# 4136
# 4137
# 4138
# 4139
# 4140
# 4141
# 4142
# 4143
# 4144
# 4145
# 4146
# 4147
# 4148
# 4149
# 4150
# 4151
# 4152
# 4153
# 4154
# 4155
# 4156
# 4157
# 4158
# 4159
# 4160
# 4161
# 4162
# 4163
# 4164
# 4165
# 4166
# 4167
# 4168
# 4169
# 4170
# 4171
# 4172
# 4173
# 4174
# 4175
# 4176
# 4177
# 4178
# 4179
# 4180
# 4181
# 4182
# 4183
# 4184
# 4185
# 4186
# 4187
# 4188
# 4189
# 4190
# 4191
# 4192
# 4193
# 4194
# 4195
# 4196
# 4197
# 4198
# 4199
# 4200
# 4201
# 4202
# 4203
# 4204
# 4205
# 4206
# 4207
# 4208
# 4209
# 4210
# 4211
# 4212
# 4213
# 4214
# 4215
# 4216
# 4217
# 4218
# 4219
# 4220
# 4221
# 4222
# 4223
# 4224
# 4225
# 4226
# 4227
# 4228
# 4229
# 4230
# 4231
# 4232
# 4233
# 4234
# 4235
# 4236
# 4237
# 4238
# 4239
# 4240
# 4241
# 4242
# 4243
# 4244
# 4245
# 4246
# 4247
# 4248
# 4249
# 4250
# 4251
# 4252
# 4253
# 4254
# 4255
# 4256
# 4257
# 4258
# 4259
# 4260
# 4261
# 4262
# 4263
# 4264
# 4265
# 4266
# 4267
# 4268
# 4269
# 4270
# 4271
# 4272
# 4273
# 4274
# 4275
# 4276
# 4277
# 4278
# 4279
# 4280
# 4281
# 4282
# 4283
# 4284
# 4285
# 4286
# 4287
# 4288
# 4289
# 4290
# 4291
# 4292
# 4293
# 4294
# 4295
# 4296
# 4297
# 4298
# 4299
# 4300
# 4301
# 4302
# 4303
# 4304
# 4305
# 4306
# 4307
# 4308
# 4309
# 4310
# 4311
# 4312
# 4313
# 4314
# 4315
# 4316
# 4317
# 4318
# 4319
# 4320
# 4321
# 4322
# 4323
# 4324
# 4325
# 4326
# 4327
# 4328
# 4329
# 4330
# 4331
# 4332
# 4333
# 4334
# 4335
# 4336
# 4337
# 4338
# 4339
# 4340
# 4341
# 4342
# 4343
# 4344
# 4345
# 4346
# 4347
# 4348
# 4349
# 4350
# 4351
# 4352
# 4353
# 4354
# 4355
# 4356
# 4357
# 4358
# 4359
# 4360
# 4361
# 4362
# 4363
# 4364
# 4365
# 4366
# 4367
# 4368
# 4369
# 4370
# 4371
# 4372
# 4373
# 4374
# 4375
# 4376
# 4377
# 4378
# 4379
# 4380
# 4381
# 4382
# 4383
# 4384
# 4385
# 4386
# 4387
# 4388
# 4389
# 4390
# 4391
# 4392
# 4393
# 4394
# 4395
# 4396
# 4397
# 4398
# 4399
# 4400
# 4401
# 4402
# 4403
# 4404
# 4405
# 4406
# 4407
# 4408
# 4409
# 4410
# 4411
# 4412
# 4413
# 4414
# 4415
# 4416
# 4417
# 4418
# 4419
# 4420
# 4421
# 4422
# 4423
# 4424
# 4425
# 4426
# 4427
# 4428
# 4429
# 4430
# 4431
# 4432
# 4433
# 4434
# 4435
# 4436
# 4437
# 4438
# 4439
# 4440
# 4441
# 4442
# 4443
# 4444
# 4445
# 4446
# 4447
# 4448
# 4449
# 4450
# 4451
# 4452
# 4453
# 4454
# 4455
# 4456
# 4457
# 4458
# 4459
# 4460
# 4461
# 4462
# 4463
# 4464
# 4465
# 4466
# 4467
# 4468
# 4469
# 4470
# 4471
# 4472
# 4473
# 4474
# 4475
# 4476
# 4477
# 4478
# 4479
# 4480
# 4481
# 4482
# 4483
# 4484
# 4485
# 4486
# 4487
# 4488
# 4489
# 4490
# 4491
# 4492
# 4493
# 4494
# 4495
# 4496
# 4497
# 4498
# 4499
# 4500
# 4501
# 4502
# 4503
# 4504
# 4505
# 4506
# 4507
# 4508
# 4509
# 4510
# 4511
# 4512
# 4513
# 4514
# 4515
# 4516
# 4517
# 4518
# 4519
# 4520
# 4521
# 4522
# 4523
# 4524
# 4525
# 4526
# 4527
# 4528
# 4529
# 4530
# 4531
# 4532
# 4533
# 4534
# 4535
# 4536
# 4537
# 4538
# 4539
# 4540
# 4541
# 4542
# 4543
# 4544
# 4545
# 4546
# 4547
# 4548
# 4549
# 4550
# 4551
# 4552
# 4553
# 4554
# 4555
# 4556
# 4557
# 4558
# 4559
# 4560
# 4561
# 4562
# 4563
# 4564
# 4565
# 4566
# 4567
# 4568
# 4569
# 4570
# 4571
# 4572
# 4573
# 4574
# 4575
# 4576
# 4577
# 4578
# 4579
# 4580
# 4581
# 4582
# 4583
# 4584
# 4585
# 4586
# 4587
# 4588
# 4589
# 4590
# 4591
# 4592
# 4593
# 4594
# 4595
# 4596
# 4597
# 4598
# 4599
# 4600
# 4601
# 4602
# 4603
# 4604
# 4605
# 4606
# 4607
# 4608
# 4609
# 4610
# 4611
# 4612
# 4613
# 4614
# 4615
# 4616
# 4617
# 4618
# 4619
# 4620
# 4621
# 4622
# 4623
# 4624
# 4625
# 4626
# 4627
# 4628
# 4629
# 4630
# 4631
# 4632
# 4633
# 4634
# 4635
# 4636
# 4637
# 4638
# 4639
# 4640
# 4641
# 4642
# 4643
# 4644
# 4645
# 4646
# 4647
# 4648
# 4649
# 4650
# 4651
# 4652
# 4653
# 4654
# 4655
# 4656
# 4657
# 4658
# 4659
# 4660
# 4661
# 4662
# 4663
# 4664
# 4665
# 4666
# 4667
# 4668
# 4669
# 4670
# 4671
# 4672
# 4673
# 4674
# 4675
# 4676
# 4677
# 4678
# 4679
# 4680
# 4681
# 4682
# 4683
# 4684
# 4685
# 4686
# 4687
# 4688
# 4689
# 4690
# 4691
# 4692
# 4693
# 4694
# 4695
# 4696
# 4697
# 4698
# 4699
# 4700
# 4701
# 4702
# 4703
# 4704
# 4705
# 4706
# 4707
# 4708
# 4709
# 4710
# 4711
# 4712
# 4713
# 4714
# 4715
# 4716
# 4717
# 4718
# 4719
# 4720
# 4721
# 4722
# 4723
# 4724
# 4725
# 4726
# 4727
# 4728
# 4729
# 4730
# 4731
# 4732
# 4733
# 4734
# 4735
# 4736
# 4737
# 4738
# 4739
# 4740
# 4741
# 4742
# 4743
# 4744
# 4745
# 4746
# 4747
# 4748
# 4749
# 4750
# 4751
# 4752
# 4753
# 4754
# 4755
# 4756
# 4757
# 4758
# 4759
# 4760
# 4761
# 4762
# 4763
# 4764
# 4765
# 4766
# 4767
# 4768
# 4769
# 4770
# 4771
# 4772
# 4773
# 4774
# 4775
# 4776
# 4777
# 4778
# 4779
# 4780
# 4781
# 4782
# 4783
# 4784
# 4785
# 4786
# 4787
# 4788
# 4789
# 4790
# 4791
# 4792
# 4793
# 4794
# 4795
# 4796
# 4797
# 4798
# 4799
# 4800
# 4801
# 4802
# 4803
# 4804
# 4805
# 4806
# 4807
# 4808
# 4809
# 4810
# 4811
# 4812
# 4813
# 4814
# 4815
# 4816
# 4817
# 4818
# 4819
# 4820
# 4821
# 4822
# 4823
# 4824
# 4825
# 4826
# 4827
# 4828
# 4829
# 4830
# 4831
# 4832
# 4833
# 4834
# 4835
# 4836
# 4837
# 4838
# 4839
# 4840
# 4841
# 4842
# 4843
# 4844
# 4845
# 4846
# 4847
# 4848
# 4849
# 4850
# 4851
# 4852
# 4853
# 4854
# 4855
# 4856
# 4857
# 4858
# 4859
# 4860
# 4861
# 4862
# 4863
# 4864
# 4865
# 4866
# 4867
# 4868
# 4869
# 4870
# 4871
# 4872
# 4873
# 4874
# 4875
# 4876
# 4877
# 4878
# 4879
# 4880
# 4881
# 4882
# 4883
# 4884
# 4885
# 4886
# 4887
# 4888
# 4889
# 4890
# 4891
# 4892
# 4893
# 4894
# 4895
# 4896
# 4897
# 4898
# 4899
# 4900
# 4901
# 4902
# 4903
# 4904
# 4905
# 4906
# 4907
# 4908
# 4909
# 4910
# 4911
# 4912
# 4913
# 4914
# 4915
# 4916
# 4917
# 4918
# 4919
# 4920
# 4921
# 4922
# 4923
# 4924
# 4925
# 4926
# 4927
# 4928
# 4929
# 4930
# 4931
# 4932
# 4933
# 4934
# 4935
# 4936
# 4937
# 4938
# 4939
# 4940
# 4941
# 4942
# 4943
# 4944
# 4945
# 4946
# 4947
# 4948
# 4949
# 4950
# 4951
# 4952
# 4953
# 4954
# 4955
# 4956
# 4957
# 4958
# 4959
# 4960
# 4961
# 4962
# 4963
# 4964
# 4965
# 4966
# 4967
# 4968
# 4969
# 4970
# 4971
# 4972
# 4973
# 4974
# 4975
# 4976
# 4977
# 4978
# 4979
# 4980
# 4981
# 4982
# 4983
# 4984
# 4985
# 4986
# 4987
# 4988
# 4989
# 4990
# 4991
# 4992
# 4993
# 4994
# 4995
# 4996
# 4997
# 4998
# 4999
# 5000
# 5001
# 5002
# 5003
# 5004
# 5005
# 5006
# 5007
# 5008
# 5009
# 5010
# 5011
# 5012
# 5013
# 5014
# 5015
# 5016
# 5017
# 5018
# 5019
# 5020
# 5021
# 5022
# 5023
# 5024
# 5025
# 5026
# 5027
# 5028
# 5029
# 5030
# 5031
# 5032
# 5033
# 5034
# 5035
# 5036
# 5037
# 5038
# 5039
# 5040
# 5041
# 5042
# 5043
# 5044
# 5045
# 5046
# 5047
# 5048
# 5049
# 5050
# 5051
# 5052
# 5053
# 5054
# 5055
# 5056
# 5057
# 5058
# 5059
# 5060
# 5061
# 5062
# 5063
# 5064
# 5065
# 5066
# 5067
# 5068
# 5069
# 5070
# 5071
# 5072
# 5073
# 5074
# 5075
# 5076
# 5077
# 5078
# 5079
# 5080
# 5081
# 5082
# 5083
# 5084
# 5085
# 5086
# 5087
# 5088
# 5089
# 5090
# 5091
# 5092
# 5093
# 5094
# 5095
# 5096
# 5097
# 5098
# 5099
# 5100
# 5101
# 5102
# 5103
# 5104
# 5105
# 5106
# 5107
# 5108
# 5109
# 5110
# 5111
# 5112
# 5113
# 5114
# 5115
# 5116
# 5117
# 5118
# 5119
# 5120
# 5121
# 5122
# 5123
# 5124
# 5125
# 5126
# 5127
# 5128
# 5129
# 5130
# 5131
# 5132
# 5133
# 5134
# 5135
# 5136
# 5137
# 5138
# 5139
# 5140
# 5141
# 5142
# 5143
# 5144
# 5145
# 5146
# 5147
# 5148
# 5149
# 5150
# 5151
# 5152
# 5153
# 5154
# 5155
# 5156
# 5157
# 5158
# 5159
# 5160
# 5161
# 5162
# 5163
# 5164
# 5165
# 5166
# 5167
# 5168
# 5169
# 5170
# 5171
# 5172
# 5173
# 5174
# 5175
# 5176
# 5177
# 5178
# 5179
# 5180
# 5181
# 5182
# 5183
# 5184
# 5185
# 5186
# 5187
# 5188
# 5189
# 5190
# 5191
# 5192
# 5193
# 5194
# 5195
# 5196
# 5197
# 5198
# 5199
# 5200
# 5201
# 5202
# 5203
# 5204
# 5205
# 5206
# 5207
# 5208
# 5209
# 5210
# 5211
# 5212
# 5213
# 5214
# 5215
# 5216
# 5217
# 5218
# 5219
# 5220
# 5221
# 5222
# 5223
# 5224
# 5225
# 5226
# 5227
# 5228
# 5229
# 5230
# 5231
# 5232
# 5233
# 5234
# 5235
# 5236
# 5237
# 5238
# 5239
# 5240
# 5241
# 5242
# 5243
# 5244
# 5245
# 5246
# 5247
# 5248
# 5249
# 5250
# 5251
# 5252
# 5253
# 5254
# 5255
# 5256
# 5257
# 5258
# 5259
# 5260
# 5261
# 5262
# 5263
# 5264
# 5265
# 5266
# 5267
# 5268
# 5269
# 5270
# 5271
# 5272
# 5273
# 5274
# 5275
# 5276
# 5277
# 5278
# 5279
# 5280
# 5281
# 5282
# 5283
# 5284
# 5285
# 5286
# 5287
# 5288
# 5289
# 5290
# 5291
# 5292
# 5293
# 5294
# 5295
# 5296
# 5297
# 5298
# 5299
# 5300
# 5301
# 5302
# 5303
# 5304
# 5305
# 5306
# 5307
# 5308
# 5309
# 5310
# 5311
# 5312
# 5313
# 5314
# 5315
# 5316
# 5317
# 5318
# 5319
# 5320
# 5321
# 5322
# 5323
# 5324
# 5325
# 5326
# 5327
# 5328
# 5329
# 5330
# 5331
# 5332
# 5333
# 5334
# 5335
# 5336
# 5337
# 5338
# 5339
# 5340
# 5341
# 5342
# 5343
# 5344
# 5345
# 5346
# 5347
# 5348
# 5349
# 5350
# 5351
# 5352
# 5353
# 5354
# 5355
# 5356
# 5357
# 5358
# 5359
# 5360
# 5361
# 5362
# 5363
# 5364
# 5365
# 5366
# 5367
# 5368
# 5369
# 5370
# 5371
# 5372
# 5373
# 5374
# 5375
# 5376
# 5377
# 5378
# 5379
# 5380
# 5381
# 5382
# 5383
# 5384
# 5385
# 5386
# 5387
# 5388
# 5389
# 5390
# 5391
# 5392
# 5393
# 5394
# 5395
# 5396
# 5397
# 5398
# 5399
# 5400
# 5401
# 5402
# 5403
# 5404
# 5405
# 5406
# 5407
# 5408
# 5409
# 5410
# 5411
# 5412
# 5413
# 5414
# 5415
# 5416
# 5417
# 5418
# 5419
# 5420
# 5421
# 5422
# 5423
# 5424
# 5425
# 5426
# 5427
# 5428
# 5429
# 5430
# 5431
# 5432
# 5433
# 5434
# 5435
# 5436
# 5437
# 5438
# 5439
# 5440
# 5441
# 5442
# 5443
# 5444
# 5445
# 5446
# 5447
# 5448
# 5449
# 5450
# 5451
# 5452
# 5453
# 5454
# 5455
# 5456
# 5457
# 5458
# 5459
# 5460
# 5461
# 5462
# 5463
# 5464
# 5465
# 5466
# 5467
# 5468
# 5469
# 5470
# 5471
# 5472
# 5473
# 5474
# 5475
# 5476
# 5477
# 5478
# 5479
# 5480
# 5481
# 5482
# 5483
# 5484
# 5485
# 5486
# 5487
# 5488
# 5489
# 5490
# 5491
# 5492
# 5493
# 5494
# 5495
# 5496
# 5497
# 5498
# 5499
# 5500
# 5501
# 5502
# 5503
# 5504
# 5505
# 5506
# 5507
# 5508
# 5509
# 5510
# 5511
# 5512
# 5513
# 5514
# 5515
# 5516
# 5517
# 5518
# 5519
# 5520
# 5521
# 5522
# 5523
# 5524
# 5525
# 5526
# 5527
# 5528
# 5529
# 5530
# 5531
# 5532
# 5533
# 5534
# 5535
# 5536
# 5537
# 5538
# 5539
# 5540
# 5541
# 5542
# 5543
# 5544
# 5545
# 5546
# 5547
# 5548
# 5549
# 5550
# 5551
# 5552
# 5553
# 5554
# 5555
# 5556
# 5557
# 5558
# 5559
# 5560
# 5561
# 5562
# 5563
# 5564
# 5565
# 5566
# 5567
# 5568
# 5569
# 5570
# 5571
# 5572
# 5573
# 5574
# 5575
# 5576
# 5577
# 5578
# 5579
# 5580
# 5581
# 5582
# 5583
# 5584
# 5585
# 5586
# 5587
# 5588
# 5589
# 5590
# 5591
# 5592
# 5593
# 5594
# 5595
# 5596
# 5597
# 5598
# 5599
# 5600
# 5601
# 5602
# 5603
# 5604
# 5605
# 5606
# 5607
# 5608
# 5609
# 5610
# 5611
# 5612
# 5613
# 5614
# 5615
# 5616
# 5617
# 5618
# 5619
# 5620
# 5621
# 5622
# 5623
# 5624
# 5625
# 5626
# 5627
# 5628
# 5629
# 5630
# 5631
# 5632
# 5633
# 5634
# 5635
# 5636
# 5637
# 5638
# 5639
# 5640
# 5641
# 5642
# 5643
# 5644
# 5645
# 5646
# 5647
# 5648
# 5649
# 5650
# 5651
# 5652
# 5653
# 5654
# 5655
# 5656
# 5657
# 5658
# 5659
# 5660
# 5661
# 5662
# 5663
# 5664
# 5665
# 5666
# 5667
# 5668
# 5669
# 5670
# 5671
# 5672
# 5673
# 5674
# 5675
# 5676
# 5677
# 5678
# 5679
# 5680
# 5681
# 5682
# 5683
# 5684
# 5685
# 5686
# 5687
# 5688
# 5689
# 5690
# 5691
# 5692
# 5693
# 5694
# 5695
# 5696
# 5697
# 5698
# 5699
# 5700
# 5701
# 5702
# 5703
# 5704
# 5705
# 5706
# 5707
# 5708
# 5709
# 5710
# 5711
# 5712
# 5713
# 5714
# 5715
# 5716
# 5717
# 5718
# 5719
# 5720
# 5721
# 5722
# 5723
# 5724
# 5725
# 5726
# 5727
# 5728
# 5729
# 5730
# 5731
# 5732
# 5733
# 5734
# 5735
# 5736
# 5737
# 5738
# 5739
# 5740
# 5741
# 5742
# 5743
# 5744
# 5745
# 5746
# 5747
# 5748
# 5749
# 5750
# 5751
# 5752
# 5753
# 5754
# 5755
# 5756
# 5757
# 5758
# 5759
# 5760
# 5761
# 5762
# 5763
# 5764
# 5765
# 5766
# 5767
# 5768
# 5769
# 5770
# 5771
# 5772
# 5773
# 5774
# 5775
# 5776
# 5777
# 5778
# 5779
# 5780
# 5781
# 5782
# 5783
# 5784
# 5785
# 5786
# 5787
# 5788
# 5789
# 5790
# 5791
# 5792
# 5793
# 5794
# 5795
# 5796
# 5797
# 5798
# 5799
# 5800
# 5801
# 5802
# 5803
# 5804
# 5805
# 5806
# 5807
# 5808
# 5809
# 5810
# 5811
# 5812
# 5813
# 5814
# 5815
# 5816
# 5817
# 5818
# 5819
# 5820
# 5821
# 5822
# 5823
# 5824
# 5825
# 5826
# 5827
# 5828
# 5829
# 5830
# 5831
# 5832
# 5833
# 5834
# 5835
# 5836
# 5837
# 5838
# 5839
# 5840
# 5841
# 5842
# 5843
# 5844
# 5845
# 5846
# 5847
# 5848
# 5849
# 5850
# 5851
# 5852
# 5853
# 5854
# 5855
# 5856
# 5857
# 5858
# 5859
# 5860
# 5861
# 5862
# 5863
# 5864
# 5865
# 5866
# 5867
# 5868
# 5869
# 5870
# 5871
# 5872
# 5873
# 5874
# 5875
# 5876
# 5877
# 5878
# 5879
# 5880
# 5881
# 5882
# 5883
# 5884
# 5885
# 5886
# 5887
# 5888
# 5889
# 5890
# 5891
# 5892
# 5893
# 5894
# 5895
# 5896
# 5897
# 5898
# 5899
# 5900
# 5901
# 5902
# 5903
# 5904
# 5905
# 5906
# 5907
# 5908
# 5909
# 5910
# 5911
# 5912
# 5913
# 5914
# 5915
# 5916
# 5917
# 5918
# 5919
# 5920
# 5921
# 5922
# 5923
# 5924
# 5925
# 5926
# 5927
# 5928
# 5929
# 5930
# 5931
# 5932
# 5933
# 5934
# 5935
# 5936
# 5937
# 5938
# 5939
# 5940
# 5941
# 5942
# 5943
# 5944
# 5945
# 5946
# 5947
# 5948
# 5949
# 5950
# 5951
# 5952
# 5953
# 5954
# 5955
# 5956
# 5957
# 5958
# 5959
# 5960
# 5961
# 5962
# 5963
# 5964
# 5965
# 5966
# 5967
# 5968
# 5969
# 5970
# 5971
# 5972
# 5973
# 5974
# 5975
# 5976
# 5977
# 5978
# 5979
# 5980
# 5981
# 5982
# 5983
# 5984
# 5985
# 5986
# 5987
# 5988
# 5989
# 5990
# 5991
# 5992
# 5993
# 5994
# 5995
# 5996
# 5997
# 5998
# 5999
# 6000
# 6001
# 6002
# 6003
# 6004
# 6005
# 6006
# 6007
# 6008
# 6009
# 6010
# 6011
# 6012
# 6013
# 6014
# 6015
# 6016
# 6017
# 6018
# 6019
# 6020
# 6021
# 6022
# 6023
# 6024
# 6025
# 6026
# 6027
# 6028
# 6029
# 6030
# 6031
# 6032
# 6033
# 6034
# 6035
# 6036
# 6037
# 6038
# 6039
# 6040
# 6041
# 6042
# 6043
# 6044
# 6045
# 6046
# 6047
# 6048
# 6049
# 6050
# 6051
# 6052
# 6053
# 6054
# 6055
# 6056
# 6057
# 6058
# 6059
# 6060
# 6061
# 6062
# 6063
# 6064
# 6065
# 6066
# 6067
# 6068
# 6069
# 6070
# 6071
# 6072
# 6073
# 6074
# 6075
# 6076
# 6077
# 6078
# 6079
# 6080
# 6081
# 6082
# 6083
# 6084
# 6085
# 6086
# 6087
# 6088
# 6089
# 6090
# 6091
# 6092
# 6093
# 6094
# 6095
# 6096
# 6097
# 6098
# 6099
# 6100
# 6101
# 6102
# 6103
# 6104
# 6105
# 6106
# 6107
# 6108
# 6109
# 6110
# 6111
# 6112
# 6113
# 6114
# 6115
# 6116
# 6117
# 6118
# 6119
# 6120
# 6121
# 6122
# 6123
# 6124
# 6125
# 6126
# 6127
# 6128
# 6129
# 6130
# 6131
# 6132
# 6133
# 6134
# 6135
# 6136
# 6137
# 6138
# 6139
# 6140
# 6141
# 6142
# 6143
# 6144
# 6145
# 6146
# 6147
# 6148
# 6149
# 6150
# 6151
# 6152
# 6153
# 6154
# 6155
# 6156
# 6157
# 6158
# 6159
# 6160
# 6161
# 6162
# 6163
# 6164
# 6165
# 6166
# 6167
# 6168
# 6169
# 6170
# 6171
# 6172
# 6173
# 6174
# 6175
# 6176
# 6177
# 6178
# 6179
# 6180
# 6181
# 6182
# 6183
# 6184
# 6185
# 6186
# 6187
# 6188
# 6189
# 6190
# 6191
# 6192
# 6193
# 6194
# 6195
# 6196
# 6197
# 6198
# 6199
# 6200
# 6201
# 6202
# 6203
# 6204
# 6205
# 6206
# 6207
# 6208
# 6209
# 6210
# 6211
# 6212
# 6213
# 6214
# 6215
# 6216
# 6217
# 6218
# 6219
# 6220
# 6221
# 6222
# 6223
# 6224
# 6225
# 6226
# 6227
# 6228
# 6229
# 6230
# 6231
# 6232
# 6233
# 6234
# 6235
# 6236
# 6237
# 6238
# 6239
# 6240
# 6241
# 6242
# 6243
# 6244
# 6245
# 6246
# 6247
# 6248
# 6249
# 6250
# 6251
# 6252
# 6253
# 6254
# 6255
# 6256
# 6257
# 6258
# 6259
# 6260
# 6261
# 6262
# 6263
# 6264
# 6265
# 6266
# 6267
# 6268
# 6269
# 6270
# 6271
# 6272
# 6273
# 6274
# 6275
# 6276
# 6277
# 6278
# 6279
# 6280
# 6281
# 6282
# 6283
# 6284
# 6285
# 6286
# 6287
# 6288
# 6289
# 6290
# 6291
# 6292
# 6293
# 6294
# 6295
# 6296
# 6297
# 6298
# 6299
# 6300
# 6301
# 6302
# 6303
# 6304
# 6305
# 6306
# 6307
# 6308
# 6309
# 6310
# 6311
# 6312
# 6313
# 6314
# 6315
# 6316
# 6317
# 6318
# 6319
# 6320
# 6321
# 6322
# 6323
# 6324
# 6325
# 6326
# 6327
# 6328
# 6329
# 6330
# 6331
# 6332
# 6333
# 6334
# 6335
# 6336
# 6337
# 6338
# 6339
# 6340
# 6341
# 6342
# 6343
# 6344
# 6345
# 6346
# 6347
# 6348
# 6349
# 6350
# 6351
# 6352
# 6353
# 6354
# 6355
# 6356
# 6357
# 6358
# 6359
# 6360
# 6361
# 6362
# 6363
# 6364
# 6365
# 6366
# 6367
# 6368
# 6369
# 6370
# 6371
# 6372
# 6373
# 6374
# 6375
# 6376
# 6377
# 6378
# 6379
# 6380
# 6381
# 6382
# 6383
# 6384
# 6385
# 6386
# 6387
# 6388
# 6389
# 6390
# 6391
# 6392
# 6393
# 6394
# 6395
# 6396
# 6397
# 6398
# 6399
# 6400
# 6401
# 6402
# 6403
# 6404
# 6405
# 6406
# 6407
# 6408
# 6409
# 6410
# 6411
# 6412
# 6413
# 6414
# 6415
# 6416
# 6417
# 6418
# 6419
# 6420
# 6421
# 6422
# 6423
# 6424
# 6425
# 6426
# 6427
# 6428
# 6429
# 6430
# 6431
# 6432
# 6433
# 6434
# 6435
# 6436
# 6437
# 6438
# 6439
# 6440
# 6441
# 6442
# 6443
# 6444
# 6445
# 6446
# 6447
# 6448
# 6449
# 6450
# 6451
# 6452
# 6453
# 6454
# 6455
# 6456
# 6457
# 6458
# 6459
# 6460
# 6461
# 6462
# 6463
# 6464
# 6465
# 6466
# 6467
# 6468
# 6469
# 6470
# 6471
# 6472
# 6473
# 6474
# 6475
# 6476
# 6477
# 6478
# 6479
# 6480
# 6481
# 6482
# 6483
# 6484
# 6485
# 6486
# 6487
# 6488
# 6489
# 6490
# 6491
# 6492
# 6493
# 6494
# 6495
# 6496
# 6497
# 6498
# 6499
# 6500
# 6501
# 6502
# 6503
# 6504
# 6505
# 6506
# 6507
# 6508
# 6509
# 6510
# 6511
# 6512
# 6513
# 6514
# 6515
# 6516
# 6517
# 6518
# 6519
# 6520
# 6521
# 6522
# 6523
# 6524
# 6525
# 6526
# 6527
# 6528
# 6529
# 6530
# 6531
# 6532
# 6533
# 6534
# 6535
# 6536
# 6537
# 6538
# 6539
# 6540
# 6541
# 6542
# 6543
# 6544
# 6545
# 6546
# 6547
# 6548
# 6549
# 6550
# 6551
# 6552
# 6553
# 6554
# 6555
# 6556
# 6557
# 6558
# 6559
# 6560
# 6561
# 6562
# 6563
# 6564
# 6565
# 6566
# 6567
# 6568
# 6569
# 6570
# 6571
# 6572
# 6573
# 6574
# 6575
# 6576
# 6577
# 6578
# 6579
# 6580
# 6581
# 6582
# 6583
# 6584
# 6585
# 6586
# 6587
# 6588
# 6589
# 6590
# 6591
# 6592
# 6593
# 6594
# 6595
# 6596
# 6597
# 6598
# 6599
# 6600
# 6601
# 6602
# 6603
# 6604
# 6605
# 6606
# 6607
# 6608
# 6609
# 6610
# 6611
# 6612
# 6613
# 6614
# 6615
# 6616
# 6617
# 6618
# 6619
# 6620
# 6621
# 6622
# 6623
# 6624
# 6625
# 6626
# 6627
# 6628
# 6629
# 6630
# 6631
# 6632
# 6633
# 6634
# 6635
# 6636
# 6637
# 6638
# 6639
# 6640
# 6641
# 6642
# 6643
# 6644
# 6645
# 6646
# 6647
# 6648
# 6649
# 6650
# 6651
# 6652
# 6653
# 6654
# 6655
# 6656
# 6657
# 6658
# 6659
# 6660
# 6661
# 6662
# 6663
# 6664
# 6665
# 6666
# 6667
# 6668
# 6669
# 6670
# 6671
# 6672
# 6673
# 6674
# 6675
# 6676
# 6677
# 6678
# 6679
# 6680
# 6681
# 6682
# 6683
# 6684
# 6685
# 6686
# 6687
# 6688
# 6689
# 6690
# 6691
# 6692
# 6693
# 6694
# 6695
# 6696
# 6697
# 6698
# 6699
# 6700
# 6701
# 6702
# 6703
# 6704
# 6705
# 6706
# 6707
# 6708
# 6709
# 6710
# 6711
# 6712
# 6713
# 6714
# 6715
# 6716
# 6717
# 6718
# 6719
# 6720
# 6721
# 6722
# 6723
# 6724
# 6725
# 6726
# 6727
# 6728
# 6729
# 6730
# 6731
# 6732
# 6733
# 6734
# 6735
# 6736
# 6737
# 6738
# 6739
# 6740
# 6741
# 6742
# 6743
# 6744
# 6745
# 6746
# 6747
# 6748
# 6749
# 6750
# 6751
# 6752
# 6753
# 6754
# 6755
# 6756
# 6757
# 6758
# 6759
# 6760
# 6761
# 6762
# 6763
# 6764
# 6765
# 6766
# 6767
# 6768
# 6769
# 6770
# 6771
# 6772
# 6773
# 6774
# 6775
# 6776
# 6777
# 6778
# 6779
# 6780
# 6781
# 6782
# 6783
# 6784
# 6785
# 6786
# 6787
# 6788
# 6789
# 6790
# 6791
# 6792
# 6793
# 6794
# 6795
# 6796
# 6797
# 6798
# 6799
# 6800
# 6801
# 6802
# 6803
# 6804
# 6805
# 6806
# 6807
# 6808
# 6809
# 6810
# 6811
# 6812
# 6813
# 6814
# 6815
# 6816
# 6817
# 6818
# 6819
# 6820
# 6821
# 6822
# 6823
# 6824
# 6825
# 6826
# 6827
# 6828
# 6829
# 6830
# 6831
# 6832
# 6833
# 6834
# 6835
# 6836
# 6837
# 6838
# 6839
# 6840
# 6841
# 6842
# 6843
# 6844
# 6845
# 6846
# 6847
# 6848
# 6849
# 6850
# 6851
# 6852
# 6853
# 6854
# 6855
# 6856
# 6857
# 6858
# 6859
# 6860
# 6861
# 6862
# 6863
# 6864
# 6865
# 6866
# 6867
# 6868
# 6869
# 6870
# 6871
# 6872
# 6873
# 6874
# 6875
# 6876
# 6877
# 6878
# 6879
# 6880
# 6881
# 6882
# 6883
# 6884
# 6885
# 6886
# 6887
# 6888
# 6889
# 6890
# 6891
# 6892
# 6893
# 6894
# 6895
# 6896
# 6897
# 6898
# 6899
# 6900
# 6901
# 6902
# 6903
# 6904
# 6905
# 6906
# 6907
# 6908
# 6909
# 6910
# 6911
# 6912
# 6913
# 6914
# 6915
# 6916
# 6917
# 6918
# 6919
# 6920
# 6921
# 6922
# 6923
# 6924
# 6925
# 6926
# 6927
# 6928
# 6929
# 6930
# 6931
# 6932
# 6933
# 6934
# 6935
# 6936
# 6937
# 6938
# 6939
# 6940
# 6941
# 6942
# 6943
# 6944
# 6945
# 6946
# 6947
# 6948
# 6949
# 6950
# 6951
# 6952
# 6953
# 6954
# 6955
# 6956
# 6957
# 6958
# 6959
# 6960
# 6961
# 6962
# 6963
# 6964
# 6965
# 6966
# 6967
# 6968
# 6969
# 6970
# 6971
# 6972
# 6973
# 6974
# 6975
# 6976
# 6977
# 6978
# 6979
# 6980
# 6981
# 6982
# 6983
# 6984
# 6985
# 6986
# 6987
# 6988
# 6989
# 6990
# 6991
# 6992
# 6993
# 6994
# 6995
# 6996
# 6997
# 6998
# 6999
# 7000
# 7001
# 7002
# 7003
# 7004
# 7005
# 7006
# 7007
# 7008
# 7009
# 7010
# 7011
# 7012
# 7013
# 7014
# 7015
# 7016
# 7017
# 7018
# 7019
# 7020
# 7021
# 7022
# 7023
# 7024
# 7025
# 7026
# 7027
# 7028
# 7029
# 7030
# 7031
# 7032
# 7033
# 7034
# 7035
# 7036
# 7037
# 7038
# 7039
# 7040
# 7041
# 7042
# 7043
# 7044
# 7045
# 7046
# 7047
# 7048
# 7049
# 7050
# 7051
# 7052
# 7053
# 7054
# 7055
# 7056
# 7057
# 7058
# 7059
# 7060
# 7061
# 7062
# 7063
# 7064
# 7065
# 7066
# 7067
# 7068
# 7069
# 7070
# 7071
# 7072
# 7073
# 7074
# 7075
# 7076
# 7077
# 7078
# 7079
# 7080
# 7081
# 7082
# 7083
# 7084
# 7085
# 7086
# 7087
# 7088
# 7089
# 7090
# 7091
# 7092
# 7093
# 7094
# 7095
# 7096
# 7097
# 7098
# 7099
# 7100
# 7101
# 7102
# 7103
# 7104
# 7105
# 7106
# 7107
# 7108
# 7109
# 7110
# 7111
# 7112
# 7113
# 7114
# 7115
# 7116
# 7117
# 7118
# 7119
# 7120
# 7121
# 7122
# 7123
# 7124
# 7125
# 7126
# 7127
# 7128
# 7129
# 7130
# 7131
# 7132
# 7133
# 7134
# 7135
# 7136
# 7137
# 7138
# 7139
# 7140
# 7141
# 7142
# 7143
# 7144
# 7145
# 7146
# 7147
# 7148
# 7149
# 7150
# 7151
# 7152
# 7153
# 7154
# 7155
# 7156
# 7157
# 7158
# 7159
# 7160
# 7161
# 7162
# 7163
# 7164
# 7165
# 7166
# 7167
# 7168
# 7169
# 7170
# 7171
# 7172
# 7173
# 7174
# 7175
# 7176
# 7177
# 7178
# 7179
# 7180
# 7181
# 7182
# 7183
# 7184
# 7185
# 7186
# 7187
# 7188
# 7189
# 7190
# 7191
# 7192
# 7193
# 7194
# 7195
# 7196
# 7197
# 7198
# 7199
# 7200
# 7201
# 7202
# 7203
# 7204
# 7205
# 7206
# 7207
# 7208
# 7209
# 7210
# 7211
# 7212
# 7213
# 7214
# 7215
# 7216
# 7217
# 7218
# 7219
# 7220
# 7221
# 7222
# 7223
# 7224
# 7225
# 7226
# 7227
# 7228
# 7229
# 7230
# 7231
# 7232
# 7233
# 7234
# 7235
# 7236
# 7237
# 7238
# 7239
# 7240
# 7241
# 7242
# 7243
# 7244
# 7245
# 7246
# 7247
# 7248
# 7249
# 7250
# 7251
# 7252
# 7253
# 7254
# 7255
# 7256
# 7257
# 7258
# 7259
# 7260
# 7261
# 7262
# 7263
# 7264
# 7265
# 7266
# 7267
# 7268
# 7269
# 7270
# 7271
# 7272
# 7273
# 7274
# 7275
# 7276
# 7277
# 7278
# 7279
# 7280
# 7281
# 7282
# 7283
# 7284
# 7285
# 7286
# 7287
# 7288
# 7289
# 7290
# 7291
# 7292
# 7293
# 7294
# 7295
# 7296
# 7297
# 7298
# 7299
# 7300
# 7301
# 7302
# 7303
# 7304
# 7305
# 7306
# 7307
# 7308
# 7309
# 7310
# 7311
# 7312
# 7313
# 7314
# 7315
# 7316
# 7317
# 7318
# 7319
# 7320
# 7321
# 7322
# 7323
# 7324
# 7325
# 7326
# 7327
# 7328
# 7329
# 7330
# 7331
# 7332
# 7333
# 7334
# 7335
# 7336
# 7337
# 7338
# 7339
# 7340
# 7341
# 7342
# 7343
# 7344
# 7345
# 7346
# 7347
# 7348
# 7349
# 7350
# 7351
# 7352
# 7353
# 7354
# 7355
# 7356
# 7357
# 7358
# 7359
# 7360
# 7361
# 7362
# 7363
# 7364
# 7365
# 7366
# 7367
# 7368
# 7369
# 7370
# 7371
# 7372
# 7373
# 7374
# 7375
# 7376
# 7377
# 7378
# 7379
# 7380
# 7381
# 7382
# 7383
# 7384
# 7385
# 7386
# 7387
# 7388
# 7389
# 7390
# 7391
# 7392
# 7393
# 7394
# 7395
# 7396
# 7397
# 7398
# 7399
# 7400
# 7401
# 7402
# 7403
# 7404
# 7405
# 7406
# 7407
# 7408
# 7409
# 7410
# 7411
# 7412
# 7413
# 7414
# 7415
# 7416
# 7417
# 7418
# 7419
# 7420
# 7421
# 7422
# 7423
# 7424
# 7425
# 7426
# 7427
# 7428
# 7429
# 7430
# 7431
# 7432
# 7433
# 7434
# 7435
# 7436
# 7437
# 7438
# 7439
# 7440
# 7441
# 7442
# 7443
# 7444
# 7445
# 7446
# 7447
# 7448
# 7449
# 7450
# 7451
# 7452
# 7453
# 7454
# 7455
# 7456
# 7457
# 7458
# 7459
# 7460
# 7461
# 7462
# 7463
# 7464
# 7465
# 7466
# 7467
# 7468
# 7469
# 7470
# 7471
# 7472
# 7473
# 7474
# 7475
# 7476
# 7477
# 7478
# 7479
# 7480
# 7481
# 7482
# 7483
# 7484
# 7485
# 7486
# 7487
# 7488
# 7489
# 7490
# 7491
# 7492
# 7493
# 7494
# 7495
# 7496
# 7497
# 7498
# 7499
# 7500
# 7501
# 7502
# 7503
# 7504
# 7505
# 7506
# 7507
# 7508
# 7509
# 7510
# 7511
# 7512
# 7513
# 7514
# 7515
# 7516
# 7517
# 7518
# 7519
# 7520
# 7521
# 7522
# 7523
# 7524
# 7525
# 7526
# 7527
# 7528
# 7529
# 7530
# 7531
# 7532
# 7533
# 7534
# 7535
# 7536
# 7537
# 7538
# 7539
# 7540
# 7541
# 7542
# 7543
# 7544
# 7545
# 7546
# 7547
# 7548
# 7549
# 7550
# 7551
# 7552
# 7553
# 7554
# 7555
# 7556
# 7557
# 7558
# 7559
# 7560
# 7561
# 7562
# 7563
# 7564
# 7565
# 7566
# 7567
# 7568
# 7569
# 7570
# 7571
# 7572
# 7573
# 7574
# 7575
# 7576
# 7577
# 7578
# 7579
# 7580
# 7581
# 7582
# 7583
# 7584
# 7585
# 7586
# 7587
# 7588
# 7589
# 7590
# 7591
# 7592
# 7593
# 7594
# 7595
# 7596
# 7597
# 7598
# 7599
# 7600
# 7601
# 7602
# 7603
# 7604
# 7605
# 7606
# 7607
# 7608
# 7609
# 7610
# 7611
# 7612
# 7613
# 7614
# 7615
# 7616
# 7617
# 7618
# 7619
# 7620
# 7621
# 7622
# 7623
# 7624
# 7625
# 7626
# 7627
# 7628
# 7629
# 7630
# 7631
# 7632
# 7633
# 7634
# 7635
# 7636
# 7637
# 7638
# 7639
# 7640
# 7641
# 7642
# 7643
# 7644
# 7645
# 7646
# 7647
# 7648
# 7649
# 7650
# 7651
# 7652
# 7653
# 7654
# 7655
# 7656
# 7657
# 7658
# 7659
# 7660
# 7661
# 7662
# 7663
# 7664
# 7665
# 7666
# 7667
# 7668
# 7669
# 7670
# 7671
# 7672
# 7673
# 7674
# 7675
# 7676
# 7677
# 7678
# 7679
# 7680
# 7681
# 7682
# 7683
# 7684
# 7685
# 7686
# 7687
# 7688
# 7689
# 7690
# 7691
# 7692
# 7693
# 7694
# 7695
# 7696
# 7697
# 7698
# 7699
# 7700
# 7701
# 7702
# 7703
# 7704
# 7705
# 7706
# 7707
# 7708
# 7709
# 7710
# 7711
# 7712
# 7713
# 7714
# 7715
# 7716
# 7717
# 7718
# 7719
# 7720
# 7721
# 7722
# 7723
# 7724
# 7725
# 7726
# 7727
# 7728
# 7729
# 7730
# 7731
# 7732
# 7733
# 7734
# 7735
# 7736
# 7737
# 7738
# 7739
# 7740
# 7741
# 7742
# 7743
# 7744
# 7745
# 7746
# 7747
# 7748
# 7749
# 7750
# 7751
# 7752
# 7753
# 7754
# 7755
# 7756
# 7757
# 7758
# 7759
# 7760
# 7761
# 7762
# 7763
# 7764
# 7765
# 7766
# 7767
# 7768
# 7769
# 7770
# 7771
# 7772
# 7773
# 7774
# 7775
# 7776
# 7777
# 7778
# 7779
# 7780
# 7781
# 7782
# 7783
# 7784
# 7785
# 7786
# 7787
# 7788
# 7789
# 7790
# 7791
# 7792
# 7793
# 7794
# 7795
# 7796
# 7797
# 7798
# 7799
# 7800
# 7801
# 7802
# 7803
# 7804
# 7805
# 7806
# 7807
# 7808
# 7809
# 7810
# 7811
# 7812
# 7813
# 7814
# 7815
# 7816
# 7817
# 7818
# 7819
# 7820
# 7821
# 7822
# 7823
# 7824
# 7825
# 7826
# 7827
# 7828
# 7829
# 7830
# 7831
# 7832
# 7833
# 7834
# 7835
# 7836
# 7837
# 7838
# 7839
# 7840
# 7841
# 7842
# 7843
# 7844
# 7845
# 7846
# 7847
# 7848
# 7849
# 7850
# 7851
# 7852
# 7853
# 7854
# 7855
# 7856
# 7857
# 7858
# 7859
# 7860
# 7861
# 7862
# 7863
# 7864
# 7865
# 7866
# 7867
# 7868
# 7869
# 7870
# 7871
# 7872
# 7873
# 7874
# 7875
# 7876
# 7877
# 7878
# 7879
# 7880
# 7881
# 7882
# 7883
# 7884
# 7885
# 7886
# 7887
# 7888
# 7889
# 7890
# 7891
# 7892
# 7893
# 7894
# 7895

# %%
gena_normal_relation.head(5)
# Out:
#        PMID                                           Sentence        ID_1  \
# 0  28470822  Transforming growth factor beta 1 (TGFB1) is d...  D000077294
# 1  28470822  Transforming growth factor beta 1 (TGFB1) is d...  D000077294
# 2  28470822  Transforming growth factor beta 1 (TGFB1) is d...  D000077294
# 3  28470822  Transforming growth factor beta 1 (TGFB1) is d...  D000077294
# 4  28470822  Transforming growth factor beta 1 (TGFB1) is d...  D000077294
#
#                                 E1 Type_E1                          Full_E1  \
# 0  Transforming growth factor beta   CHEBI  Transforming growth factor beta
# 1  Transforming growth factor beta   CHEBI  Transforming growth factor beta
# 2  Transforming growth factor beta   CHEBI  Transforming growth factor beta
# 3  Transforming growth factor beta   CHEBI  Transforming growth factor beta
# 4  Transforming growth factor beta   CHEBI  Transforming growth factor beta
#
#                                           Synonyms_1            Relation  \
# 0  Receptor, Transforming Growth Factor beta Type...  be dysregulated in
# 1  Receptor, Transforming Growth Factor beta Type...  be dysregulated in
# 2  Receptor, Transforming Growth Factor beta Type...  be dysregulated in
# 3  Receptor, Transforming Growth Factor beta Type...  be dysregulated in
# 4  Receptor, Transforming Growth Factor beta Type...  be dysregulated in
#
#          ID_2                            E2  Type_E2  \
# 0     D046589          subcortical infarcts  DISEASE
# 1     C563990  cerebral autosomal recessive  DISEASE
# 2  No_ID_MeSH                hereditary SVD  DISEASE
# 3     C563990        recessive arteriopathy  DISEASE
# 4     D054038           leukoencephalopathy  DISEASE
#
#                         Full_E2  \
# 0          subcortical infarcts
# 1  cerebral autosomal recessive
# 2                hereditary SVD
# 3        recessive arteriopathy
# 4           leukoencephalopathy
#
#                                           Synonyms_2 MeSH_E1 MeSH_E2
# 0  Dementia, Hereditary Multi-Infarct Type|Dement...
# 1  Alopecia|Cerebral Infarction|Spinal Diseases|L...
# 2                                        No synonyms
# 3  Alopecia|Cerebral Infarction|Spinal Diseases|L...
# 4  Leukoencephalopathy Syndromes, Posterior|Syndr...

# %%
print(len(gena_normal_relation[gena_normal_relation['ID_1'] == "No_ID_MeSH"]), len(gena_normal_relation[gena_normal_relation['ID_2'] == "No_ID_MeSH"]))
gena_normal_relation[["PMID", "Sentence", "ID_1", "E1", "Type_E1", "Full_E1", "MeSH_E1", "Synonyms_1", "Relation", "ID_2", "E2", "Type_E2", "Full_E2", "MeSH_E2", "Synonyms_2"]].to_csv("/content/drive/MyDrive/gena_with_ID_MESH_3.csv", index=False)

# import time
# time.sleep(5)

# from google.colab import files
# files.download(f'gena_with_ID_MESH.csv')
# Out:
# 3781 3931

# %% [markdown]
# # Get ID from Ontologies

# %%
relation_df = pd.read_csv("/content/drive/MyDrive/gena_with_ID_MESH_3.csv")
relation_df.head(5)
# Out:
#        PMID                                           Sentence        ID_1  \
# 0  28470822  Transforming growth factor beta 1 (TGFB1) is d...  D000077294
# 1  28470822  Transforming growth factor beta 1 (TGFB1) is d...  D000077294
# 2  28470822  Transforming growth factor beta 1 (TGFB1) is d...  D000077294
# 3  28470822  Transforming growth factor beta 1 (TGFB1) is d...  D000077294
# 4  28470822  Transforming growth factor beta 1 (TGFB1) is d...  D000077294
#
#                                 E1 Type_E1                          Full_E1  \
# 0  Transforming growth factor beta   CHEBI  Transforming growth factor beta
# 1  Transforming growth factor beta   CHEBI  Transforming growth factor beta
# 2  Transforming growth factor beta   CHEBI  Transforming growth factor beta
# 3  Transforming growth factor beta   CHEBI  Transforming growth factor beta
# 4  Transforming growth factor beta   CHEBI  Transforming growth factor beta
#
#   MeSH_E1                                         Synonyms_1  \
# 0     NaN  Receptor, Transforming Growth Factor beta Type...
# 1     NaN  Receptor, Transforming Growth Factor beta Type...
# 2     NaN  Receptor, Transforming Growth Factor beta Type...
# 3     NaN  Receptor, Transforming Growth Factor beta Type...
# 4     NaN  Receptor, Transforming Growth Factor beta Type...
#
#              Relation        ID_2                            E2  Type_E2  \
# 0  be dysregulated in     D046589          subcortical infarcts  DISEASE
# 1  be dysregulated in     C563990  cerebral autosomal recessive  DISEASE
# 2  be dysregulated in  No_ID_MeSH                hereditary SVD  DISEASE
# 3  be dysregulated in     C563990        recessive arteriopathy  DISEASE
# 4  be dysregulated in     D054038           leukoencephalopathy  DISEASE
#
#                         Full_E2 MeSH_E2  \
# 0          subcortical infarcts     NaN
# 1  cerebral autosomal recessive     NaN
# 2                hereditary SVD     NaN
# 3        recessive arteriopathy     NaN
# 4           leukoencephalopathy     NaN
#
#                                           Synonyms_2
# 0  Dementia, Hereditary Multi-Infarct Type|Dement...
# 1  Alopecia|Cerebral Infarction|Spinal Diseases|L...
# 2                                        No synonyms
# 3  Alopecia|Cerebral Infarction|Spinal Diseases|L...
# 4  Leukoencephalopathy Syndromes, Posterior|Syndr...

# %%
# FULL ONTOLOGY
def concat_df(file_name:str, all_ont_df:DataFrame)->DataFrame:
  """
  Concat new dataframe from a file to the given dataframe.
  """
  ont_df = pd.read_csv(file_name)[['Class ID', 'Preferred Label', 'Synonyms']]
  if file_name == "APADISORDERS.csv":
    ont_df['Preferred Label'] = ont_df['Preferred Label'].map(lambda x: x.replace("_", " ").lower())
  else:
    ont_df['Preferred Label'] = ont_df['Preferred Label'].map(lambda x: x.lower() if isinstance(x, str) else "")
  return pd.concat([all_ont_df, ont_df])

ontologies = ['SYMP.csv', 'DOID.csv', 'CHEBI.csv', 'APADISORDERS.csv', 'ASDPTO.csv', 'FMA.csv', 'MFOMD.csv']
full_ont_df = pd.read_csv(ontologies[0])[['Class ID', 'Preferred Label', 'Synonyms']]
full_ont_df['Preferred Label'] = full_ont_df['Preferred Label'].map(lambda x: x.lower())
for ont in ontologies[1:]:
  full_ont_df = concat_df(ont, full_ont_df)
full_ont_df.drop_duplicates(subset=['Class ID'], inplace=True, ignore_index=True)
full_ont_df["Vector"] = full_ont_df['Preferred Label'].map(lambda x: np.array(gena_nlp(x).vector))
full_ont_df.head(5)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: DtypeWarning: Columns (8,51,65,71,75,79) have mixed types.Specify dtype option on import or set low_memory=False.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: DtypeWarning: Columns (30,31) have mixed types.Specify dtype option on import or set low_memory=False.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: DtypeWarning: Columns (41,71,75,77,99,100,103,113,114,138,140,156,157,158,178,198) have mixed types.Specify dtype option on import or set low_memory=False.
#                                       Class ID                Preferred Label  \
# 0  http://purl.obolibrary.org/obo/SYMP_0000149  sudden onset of severe chills
# 1  http://purl.obolibrary.org/obo/SYMP_0000259              dry hacking cough
# 2  http://purl.obolibrary.org/obo/SYMP_0000729        pulmonary consolidation
# 3  http://purl.obolibrary.org/obo/SYMP_0000746                       enanthem
# 4  http://purl.obolibrary.org/obo/SYMP_0000412                        anxiety
#
#   Synonyms                                             Vector
# 0      NaN  [-0.07547201, 0.31105042, -0.02869026, -0.1448...
# 1      NaN  [-0.08133, 0.46636868, -0.01648433, -0.0966516...
# 2      NaN  [-0.022594575, 0.311132, 0.176519, -0.0930199,...
# 3      NaN  [0.397117, 0.552231, -0.245164, -0.408734, -0....
# 4      NaN  [-0.568638, -0.0604911, -0.0904757, -0.11993, ...

# %%
# Protein Dictionary
protein_df = pd.read_csv("PR.csv")
protein_dict = {}
for idx, row in protein_df.iterrows():
  if isinstance(row['Preferred Label'], str):
    synonyms = [syn.lower() for syn in (row["Synonyms"].split("|") if isinstance(row["Synonyms"], str) else [])]
    protein_dict[row['Class ID']] = [row['Preferred Label'].lower()] + synonyms
len(list(protein_dict.keys()))
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (9,10,11,14,16,18,25,30,32,47,50,52) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# 332991

# %%
def find_protein(term:str, protein_dict:dict)->tuple:
  """
  Find protein name of a term if possible
  """
  for key in protein_dict.keys():
    for protein in protein_dict[key][1:]:
      if term in re.sub('[^A-Za-z0-9]+', ' ', protein).split():
        return (key, protein_dict[key][0], '|'.join(protein_dict[key][1:]) if len(protein_dict[key]) > 1 else "No Synonyms")
  return ("No_ID_MeSH", term, "No synonyms")

def cosine_similar(vec_1:ndarray, vec_2:ndarray):
  """
  Cosine distance of 2 vectors in SpaCy
  """
  return (vec_1.dot(vec_2))/(np.linalg.norm(vec_1)*np.linalg.norm(vec_2))

def most_similar(ont_df:DataFrame, term:str, protein_dict:dict, nlp)->tuple:
  """
  Get the most similar term of a given term 
  """
  term_vector = np.array(nlp(term).vector)
  max_result = ont_df["Vector"].map(lambda x: cosine_similar(term_vector, x))
  max_similar = max_result.max()
  max_index = max_result.argmax()

  if max_similar > 0.95:
    synonyms = ont_df.loc[max_index, 'Synonyms'] if isinstance(ont_df.loc[max_index, 'Synonyms'], str) else "No synonyms"
    return (ont_df.loc[max_index, 'Class ID'], ont_df.loc[max_index, 'Preferred Label'], synonyms)
  else:
    return find_protein(term, protein_dict)

# %%
term = "n-6 polyunsaturated fatty acid"
most_similar(full_ont_df, term, protein_dict, gena_nlp)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# ('http://purl.obolibrary.org/obo/CHEBI_26208',
#  'polyunsaturated fatty acid',
#  'polyunsaturated fatty acids|PUFA|PUFAs')

# %%
ontology_dict = {}
for idx, row in relation_df.iterrows():
  print(idx)
  
  if (row["ID_1"] != "No_ID_MeSH" and row["ID_2"] != "No_ID_MeSH"):
    continue

  if row["ID_1"] == "No_ID_MeSH":
    if not ontology_dict.get(row['E1'], False):
      term_1 = ' '.join(word.lemma_ for word in gena_nlp(row["Full_E1"]))
      result_1 = most_similar(full_ont_df, term_1, protein_dict, gena_nlp)
      ontology_dict[row['E1']] = result_1
    relation_df.loc[idx, 'ID_1'], relation_df.loc[idx, 'MeSH_E1'], relation_df.loc[idx, 'Synonyms_1'] = ontology_dict[row['E1']]
  
  if row["ID_2"] == "No_ID_MeSH":
    if not ontology_dict.get(row['E2'], False):
      term_2 = ' '.join(word.lemma_ for word in gena_nlp(row["Full_E2"]))
      result_2 = most_similar(full_ont_df, term_2, protein_dict, gena_nlp)
      ontology_dict[row['E2']] = result_2
    relation_df.loc[idx, 'ID_2'], relation_df.loc[idx, 'MeSH_E2'], relation_df.loc[idx, 'Synonyms_2'] = ontology_dict[row['E2']]
# Out:
# 0
# 1
# 2
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 407
# 408
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 409
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 410
# 411
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 412
# 413
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 414
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 415
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 416
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 417
# 418
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 419
# 420
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 421
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 422
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 423
# 424
# 425
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 426
# 427
# ...
# 7567
# 7568
# 7569
# 7570
# 7571
# 7572
# 7573
# 7574
# 7575
# 7576
# 7577
# 7578
# 7579
# 7580
# 7581
# 7582
# 7583
# 7584
# 7585
# 7586
# 7587
# 7588
# 7589
# 7590
# 7591
# 7592
# 7593
# 7594
# 7595
# 7596
# 7597
# 7598
# 7599
# 7600
# 7601
# 7602
# 7603
# 7604
# 7605
# 7606
# 7607
# 7608
# 7609
# 7610
# 7611
# 7612
# 7613
# 7614
# 7615
# 7616
# 7617
# 7618
# 7619
# 7620
# 7621
# 7622
# 7623
# 7624
# 7625
# 7626
# 7627
# 7628
# 7629
# 7630
# 7631
# 7632
# 7633
# 7634
# 7635
# 7636
# 7637
# 7638
# 7639
# 7640
# 7641
# 7642
# 7643
# 7644
# 7645
# 7646
# 7647
# 7648
# 7649
# 7650
# 7651
# 7652
# 7653
# 7654
# 7655
# 7656
# 7657
# 7658
# 7659
# 7660
# 7661
# 7662
# 7663
# 7664
# 7665
# 7666
# 7667
# 7668
# 7669
# 7670
# 7671
# 7672
# 7673
# 7674
# 7675
# 7676
# 7677
# 7678
# 7679
# 7680
# 7681
# 7682
# 7683
# 7684
# 7685
# 7686
# 7687
# 7688
# 7689
# 7690
# 7691
# 7692
# 7693
# 7694
# 7695
# 7696
# 7697
# 7698
# 7699
# 7700
# 7701
# 7702
# 7703
# 7704
# 7705
# 7706
# 7707
# 7708
# 7709
# 7710
# 7711
# 7712
# 7713
# 7714
# 7715
# 7716
# 7717
# 7718
# 7719
# 7720
# 7721
# 7722
# 7723
# 7724
# 7725
# 7726
# 7727
# 7728
# 7729
# 7730
# 7731
# 7732
# 7733
# 7734
# 7735
# 7736
# 7737
# 7738
# 7739
# 7740
# 7741
# 7742
# 7743
# 7744
# 7745
# 7746
# 7747
# 7748
# 7749
# 7750
# 7751
# 7752
# 7753
# 7754
# 7755
# 7756
# 7757
# 7758
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7759
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7760
# 7761
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7762
# 7763
# 7764
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7765
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7766
# 7767
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7768
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7769
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7770
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7771
# 7772
# 7773
# 7774
# 7775
# 7776
# 7777
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7778
# 7779
# 7780
# 7781
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7782
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7783
# 7784
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7785
# 7786
# 7787
# 7788
# 7789
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7790
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7791
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7792
# 7793
# 7794
# 7795
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7796
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7797
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7798
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7799
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7800
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7801
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7802
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7803
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7804
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7805
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7806
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7807
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7808
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7809
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7810
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7811
# 7812
# 7813
# 7814
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7815
# 7816
# 7817
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7818
# 7819
# 7820
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7821
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7822
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7823
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7824
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7825
# 7826
# 7827
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7828
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7829
# 7830
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7831
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7832
# 7833
# 7834
# 7835
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7836
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7837
# 7838
# 7839
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7840
# 7841
# 7842
# 7843
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7844
# 7845
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7846
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7847
# 7848
# 7849
# 7850
# 7851
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7852
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7853
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7854
# 7855
# 7856
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7857
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7858
# 7859
# 7860
# 7861
# 7862
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7863
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7864
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7865
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7866
# 7867
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7868
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7869
# 7870
# 7871
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7872
# 7873
# 7874
# 7875
# 7876
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7877
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7878
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7879
# 7880
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7881
# 7882
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7883
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7884
# 7885
# 7886
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7887
# 7888
# 7889
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7890
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7891
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7892
# 7893
# 7894
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# 7895
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in float_scalars
#   from ipykernel import kernelapp as app

# %%
print(len(relation_df[relation_df['ID_1'] != "No_ID_MeSH"]), len(relation_df[relation_df['ID_2'] != "No_ID_MeSH"]))
relation_df.to_csv("/content/drive/MyDrive/gena_update_Ontologies_full_3.csv", index=False)

# import time
# time.sleep(5)
# from google.colab import files
# files.download('nah_update_Ontologies_full.csv')
# Out:
# 4571 4432

# %% [markdown]
# # Create new ID for new terms

# %%
relation_df = pd.concat([pd.read_csv("/content/drive/MyDrive/gena_update_Ontologies_full.csv"),
                         pd.read_csv("/content/drive/MyDrive/gena_update_Ontologies_full_2.csv"),
                         pd.read_csv("/content/drive/MyDrive/gena_update_Ontologies_full_3.csv")]).reset_index(drop=True)
relation_df.head(5)
# Out:
#        PMID                                           Sentence        ID_1  \
# 0  31196764  Flibanserin, a multifunctional serotonin recep...     C098107
# 1  31196764  Flibanserin, a multifunctional serotonin recep...     C098107
# 2  31196764  Flibanserin, a multifunctional serotonin recep...  No_ID_MeSH
# 3  31196764  Flibanserin, a multifunctional serotonin recep...  No_ID_MeSH
# 4  27584019  Obesity is associated with reduced testosteron...     D063766
#
#                                            E1   Type_E1  \
# 0                                 Flibanserin  CHEMICAL
# 1                                 Flibanserin  CHEMICAL
# 2  multifunctional serotonin receptor agonist  CHEMICAL
# 3  multifunctional serotonin receptor agonist  CHEMICAL
# 4                                     Obesity   DISEASE
#
#                                       Full_E1  \
# 0                                 Flibanserin
# 1                                 Flibanserin
# 2  multifunctional serotonin receptor agonist
# 3  multifunctional serotonin receptor agonist
# 4                                     Obesity
#
#                                       MeSH_E1  \
# 0         flibanserin [Supplementary Concept]
# 1         flibanserin [Supplementary Concept]
# 2  multifunctional serotonin receptor agonist
# 3  multifunctional serotonin receptor agonist
# 4                           Pediatric Obesity
#
#                                           Synonyms_1  \
# 0                                     Benzimidazoles
# 1                                     Benzimidazoles
# 2                                        No synonyms
# 3                                        No synonyms
# 4  Obesity, Pediatric|Obesity in Childhood|Childh...
#
#                                             Relation        ID_2  \
# 0  be approved in united states and canada for tr...  No_ID_MeSH
# 1  be approved in united states and canada for tr...     D020018
# 2  be approved in united states and canada for tr...  No_ID_MeSH
# 3  be approved in united states and canada for tr...     D020018
# 4                                 be associated with  No_ID_MeSH
#
#                                                   E2        Type_E2  \
# 0  acquired generalized hypoactive sexual desire ...  MENTAL_HEALTH
# 1                                               HSDD        DISEASE
# 2  acquired generalized hypoactive sexual desire ...  MENTAL_HEALTH
# 3                                               HSDD        DISEASE
# 4                               reduced testosterone       CHEMICAL
#
#                                              Full_E2  \
# 0  acquired generalized hypoactive sexual desire ...
# 1                  hypoactive sexual desire disorder
# 2  acquired generalized hypoactive sexual desire ...
# 3                  hypoactive sexual desire disorder
# 4                               reduced testosterone
#
#                                              MeSH_E2  \
# 0  acquired generalized hypoactive sexual desire ...
# 1                 Sexual Dysfunctions, Psychological
# 2  acquired generalized hypoactive sexual desire ...
# 3                 Sexual Dysfunctions, Psychological
# 4                               reduced testosterone
#
#                                           Synonyms_2
# 0                                        No synonyms
# 1  Dysfunction, Psychological Sexual|Dysfunctions...
# 2                                        No synonyms
# 3  Dysfunction, Psychological Sexual|Dysfunctions...
# 4                                        No synonyms

# %%
available_df = pd.read_csv("available_fad.csv")
available_df.columns = ['ID_1', 'E1', 'Relation', 'ID_2', 'E2']
available_df['Full_E1'], available_df['Full_E2'] = available_df['E1'].tolist(), available_df['E2'].tolist()
available_df['MeSH_E1'], available_df['MeSH_E2'] = available_df['E1'].tolist(), available_df['E2'].tolist()
available_df['Type_E1'] = ['CHEMICAL']*2434 + ['DISEASE']*(len(available_df)-2434)
available_df['Type_E2'] = ['DISEASE']*2434 + ['NUTRITION']*(len(available_df)-2434)

# %%
available_df['PMID'] = ['BC5CDR']*2434 + ['DOID']*(len(available_df)-2434)
available_df['Sentence'] = available_df['Synonyms_1'] = available_df['Synonyms_2'] = ['']*len(available_df)
available_df = available_df[relation_df.columns]
relation_df = pd.concat([relation_df, available_df], axis=0).dropna().reset_index(drop=True)
relation_df.head(5)
# Out:
#        PMID                                           Sentence        ID_1  \
# 0  31196764  Flibanserin, a multifunctional serotonin recep...     C098107
# 1  31196764  Flibanserin, a multifunctional serotonin recep...     C098107
# 2  31196764  Flibanserin, a multifunctional serotonin recep...  No_ID_MeSH
# 3  31196764  Flibanserin, a multifunctional serotonin recep...  No_ID_MeSH
# 4  27584019  Obesity is associated with reduced testosteron...     D063766
#
#                                            E1   Type_E1  \
# 0                                 Flibanserin  CHEMICAL
# 1                                 Flibanserin  CHEMICAL
# 2  multifunctional serotonin receptor agonist  CHEMICAL
# 3  multifunctional serotonin receptor agonist  CHEMICAL
# 4                                     Obesity   DISEASE
#
#                                       Full_E1  \
# 0                                 Flibanserin
# 1                                 Flibanserin
# 2  multifunctional serotonin receptor agonist
# 3  multifunctional serotonin receptor agonist
# 4                                     Obesity
#
#                                       MeSH_E1  \
# 0         flibanserin [Supplementary Concept]
# 1         flibanserin [Supplementary Concept]
# 2  multifunctional serotonin receptor agonist
# 3  multifunctional serotonin receptor agonist
# 4                           Pediatric Obesity
#
#                                           Synonyms_1  \
# 0                                     Benzimidazoles
# 1                                     Benzimidazoles
# 2                                        No synonyms
# 3                                        No synonyms
# 4  Obesity, Pediatric|Obesity in Childhood|Childh...
#
#                                             Relation        ID_2  \
# 0  be approved in united states and canada for tr...  No_ID_MeSH
# 1  be approved in united states and canada for tr...     D020018
# 2  be approved in united states and canada for tr...  No_ID_MeSH
# 3  be approved in united states and canada for tr...     D020018
# 4                                 be associated with  No_ID_MeSH
#
#                                                   E2        Type_E2  \
# 0  acquired generalized hypoactive sexual desire ...  MENTAL_HEALTH
# 1                                               HSDD        DISEASE
# 2  acquired generalized hypoactive sexual desire ...  MENTAL_HEALTH
# 3                                               HSDD        DISEASE
# 4                               reduced testosterone       CHEMICAL
#
#                                              Full_E2  \
# 0  acquired generalized hypoactive sexual desire ...
# 1                  hypoactive sexual desire disorder
# 2  acquired generalized hypoactive sexual desire ...
# 3                  hypoactive sexual desire disorder
# 4                               reduced testosterone
#
#                                              MeSH_E2  \
# 0  acquired generalized hypoactive sexual desire ...
# 1                 Sexual Dysfunctions, Psychological
# 2  acquired generalized hypoactive sexual desire ...
# 3                 Sexual Dysfunctions, Psychological
# 4                               reduced testosterone
#
#                                           Synonyms_2
# 0                                        No synonyms
# 1  Dysfunction, Psychological Sexual|Dysfunctions...
# 2                                        No synonyms
# 3  Dysfunction, Psychological Sexual|Dysfunctions...
# 4                                        No synonyms

# %%
relation_df[relation_df['ID_1'].isna()]
# Out:
# Empty DataFrame
# Columns: [PMID, Sentence, ID_1, E1, Type_E1, Full_E1, MeSH_E1, Synonyms_1, Relation, ID_2, E2, Type_E2, Full_E2, MeSH_E2, Synonyms_2]
# Index: []

# %%
new_count = 0
new_term_id_dict = {}
for idx, row in relation_df.iterrows():
  print(idx)
  if row['ID_1'].startswith("No"):
    if new_term_id_dict.get(row['E1']):
      relation_df.loc[idx, 'ID_1'] = new_term_id_dict[row['E1']]
    else:
      new_id = "NEW" + "{:05d}".format(new_count)
      relation_df.loc[idx, 'ID_1'] = new_id
      new_term_id_dict[row['E1']] = new_id
      new_count += 1

  if row['ID_2'].startswith("No"):
    if new_term_id_dict.get(row['E2']):
      relation_df.loc[idx, 'ID_2'] = new_term_id_dict[row['E2']]
    else:
      new_id = "NEW" + "{:05d}".format(new_count)
      relation_df.loc[idx, 'ID_2'] = new_id
      new_term_id_dict[row['E2']] = new_id
      new_count += 1
# Check if there is no-id terms
len(relation_df[relation_df['ID_1'] == 'No_ID_MeSH']), len(relation_df[relation_df['ID_2'] == 'No_ID_MeSH'])
# Out:
# Streaming output truncated to the last 5000 lines.
# 40553
# 40554
# 40555
# 40556
# 40557
# 40558
# 40559
# 40560
# 40561
# 40562
# 40563
# 40564
# 40565
# 40566
# 40567
# 40568
# 40569
# 40570
# 40571
# 40572
# 40573
# 40574
# 40575
# 40576
# 40577
# 40578
# 40579
# 40580
# 40581
# 40582
# 40583
# 40584
# 40585
# 40586
# 40587
# 40588
# 40589
# 44927
# 44928
# 44929
# 44930
# 44931
# 44932
# 44933
# 44934
# 44935
# 44936
# 44937
# 44938
# 44939
# 44940
# 44941
# 44942
# 44943
# 44944
# 44945
# 44946
# 44947
# 44948
# 44949
# 44950
# 44951
# 44952
# 44953
# 44954
# 44955
# 44956
# 44957
# 44958
# 44959
# 44960
# 44961
# 44962
# 44963
# 44964
# 44965
# 44966
# 44967
# 44968
# 44969
# 44970
# 44971
# 44972
# 44973
# 44974
# 44975
# 44976
# 44977
# 44978
# 44979
# 44980
# 44981
# 44982
# 44983
# 44984
# 44985
# 44986
# 44987
# 44988
# 44989
# 44990
# 44991
# 44992
# 44993
# 44994
# 44995
# 44996
# 44997
# 44998
# 44999
# 45000
# 45001
# 45002
# 45003
# 45004
# 45005
# 45006
# 45007
# 45008
# 45009
# 45010
# 45011
# 45012
# 45013
# 45014
# 45015
# 45016
# 45017
# 45018
# 45019
# 45020
# 45021
# 45022
# 45023
# 45024
# 45025
# 45026
# 45027
# 45028
# 45029
# 45030
# 45031
# 45032
# 45033
# 45034
# 45035
# 45036
# 45037
# 45038
# 45039
# 45040
# 45041
# 45042
# 45043
# 45044
# 45045
# 45046
# 45047
# 45048
# 45049
# 45050
# 45051
# 45052
# 45053
# 45054
# 45055
# 45056
# 45057
# 45058
# 45059
# 45060
# 45061
# 45062
# 45063
# 45064
# 45065
# 45066
# 45067
# 45068
# 45069
# 45070
# 45071
# 45072
# 45073
# 45074
# 45075
# 45076
# 45077
# 45078
# 45079
# 45080
# 45081
# 45082
# 45083
# 45084
# 45085
# 45086
# 45087
# 45088
# 45089
# 45090
# 45091
# 45092
# 45093
# 45094
# 45095
# 45096
# 45097
# 45098
# 45099
# 45100
# 45101
# 45102
# 45103
# 45104
# 45105
# 45106
# 45107
# 45108
# 45109
# 45110
# 45111
# 45112
# 45113
# 45114
# 45115
# 45116
# 45117
# 45118
# 45119
# 45120
# 45121
# 45122
# 45123
# 45124
# 45125
# 45126
# 45127
# 45128
# 45129
# 45130
# 45131
# 45132
# 45133
# 45134
# 45135
# 45136
# 45137
# 45138
# 45139
# 45140
# 45141
# 45142
# 45143
# 45144
# 45145
# 45146
# 45147
# 45148
# 45149
# 45150
# 45151
# 45152
# 45153
# 45154
# 45155
# 45156
# 45157
# 45158
# 45159
# 45160
# 45161
# 45162
# 45163
# 45164
# 45165
# 45166
# 45167
# 45168
# 45169
# 45170
# 45171
# 45172
# 45173
# 45174
# 45175
# 45176
# 45177
# 45178
# 45179
# 45180
# 45181
# 45182
# 45183
# 45184
# 45185
# 45186
# 45187
# 45188
# 45189
# 45190
# 45191
# 45192
# 45193
# 45194
# 45195
# 45196
# 45197
# 45198
# 45199
# 45200
# 45201
# 45202
# 45203
# 45204
# 45205
# 45206
# 45207
# 45208
# 45209
# 45210
# 45211
# 45212
# 45213
# 45214
# 45215
# 45216
# 45217
# 45218
# 45219
# 45220
# 45221
# 45222
# 45223
# 45224
# 45225
# 45226
# 45227
# 45228
# 45229
# 45230
# 45231
# 45232
# 45233
# 45234
# 45235
# 45236
# 45237
# 45238
# 45239
# 45240
# 45241
# 45242
# 45243
# 45244
# 45245
# 45246
# 45247
# 45248
# 45249
# 45250
# 45251
# 45252
# 45253
# 45254
# 45255
# 45256
# 45257
# 45258
# 45259
# 45260
# 45261
# 45262
# 45263
# 45264
# 45265
# 45266
# 45267
# 45268
# 45269
# 45270
# 45271
# 45272
# 45273
# 45274
# 45275
# 45276
# 45277
# 45278
# 45279
# 45280
# 45281
# 45282
# 45283
# 45284
# 45285
# 45286
# 45287
# 45288
# 45289
# 45290
# 45291
# 45292
# 45293
# 45294
# 45295
# 45296
# 45297
# 45298
# 45299
# 45300
# 45301
# 45302
# 45303
# 45304
# 45305
# 45306
# 45307
# 45308
# 45309
# 45310
# 45311
# 45312
# 45313
# 45314
# 45315
# 45316
# 45317
# 45318
# 45319
# 45320
# 45321
# 45322
# 45323
# 45324
# 45325
# 45326
# 45327
# 45328
# 45329
# 45330
# 45331
# 45332
# 45333
# 45334
# 45335
# 45336
# 45337
# 45338
# 45339
# 45340
# 45341
# 45342
# 45343
# 45344
# 45345
# 45346
# 45347
# 45348
# 45349
# 45350
# 45351
# 45352
# 45353
# 45354
# 45355
# 45356
# 45357
# 45358
# 45359
# 45360
# 45361
# 45362
# 45363
# 45364
# 45365
# 45366
# 45367
# 45368
# 45369
# 45370
# 45371
# 45372
# 45373
# 45374
# 45375
# 45376
# 45377
# 45378
# 45379
# 45380
# 45381
# 45382
# 45383
# 45384
# 45385
# 45386
# 45387
# 45388
# 45389
# 45390
# 45391
# 45392
# 45393
# 45394
# 45395
# 45396
# 45397
# 45398
# 45399
# 45400
# 45401
# 45402
# 45403
# 45404
# 45405
# 45406
# 45407
# 45408
# 45409
# 45410
# 45411
# 45412
# 45413
# 45414
# 45415
# 45416
# 45417
# 45418
# 45419
# 45420
# 45421
# 45422
# 45423
# 45424
# 45425
# 45426
# 45427
# 45428
# 45429
# 45430
# 45431
# 45432
# 45433
# 45434
# 45435
# 45436
# 45437
# 45438
# 45439
# 45440
# 45441
# 45442
# 45443
# 45444
# 45445
# 45446
# 45447
# 45448
# 45449
# 45450
# 45451
# 45452
# 45453
# 45454
# 45455
# 45456
# 45457
# 45458
# 45459
# 45460
# 45461
# 45462
# 45463
# 45464
# 45465
# 45466
# 45467
# 45468
# 45469
# 45470
# 45471
# 45472
# 45473
# 45474
# 45475
# 45476
# 45477
# 45478
# 45479
# 45480
# 45481
# 45482
# 45483
# 45484
# 45485
# 45486
# 45487
# 45488
# 45489
# 45490
# 45491
# 45492
# 45493
# 45494
# 45495
# 45496
# 45497
# 45498
# 45499
# 45500
# 45501
# 45502
# 45503
# 45504
# 45505
# 45506
# 45507
# 45508
# 45509
# 45510
# 45511
# 45512
# 45513
# 45514
# 45515
# 45516
# 45517
# 45518
# 45519
# 45520
# 45521
# 45522
# 45523
# 45524
# 45525
# 45526
# 45527
# 45528
# 45529
# 45530
# 45531
# 45532
# 45533
# 45534
# 45535
# 45536
# 45537
# 45538
# 45539
# 45540
# 45541
# 45542
# 45543
# 45544
# 45545
# 45546
# 45547
# 45548
# 45549
# 45550
# 45551
# 45552
# (0, 0)

# %%
relation_df.to_csv("gena_with_ID_full.csv", index=False)

# %% [markdown]
# # Prepare data for Knowledge Graph

# %% [markdown]
# ## ID and terms from papers corresponding

# %%
term_df = relation_df[['ID_1', 'E1', 'Full_E1', 'MeSH_E1', 'Synonyms_1', 'Type_E1', 'ID_2', 'E2', 'Full_E2', 'MeSH_E2', 'Synonyms_2', 'Type_E2']].fillna({'Synonyms_1': 'No synonyms', 'Synonyms_2': 'No synonyms'})
term_df.columns = ['ID_1', 'Paper_term_1', 'Full_paper_term_1', 'Standard_term_1', 'Synonyms_1', 'Type_E1', 'ID_2', 'Paper_term_2', 'Full_paper_term_2', 'Standard_term_2', 'Synonyms_2', 'Type_E2']
term_df.head(5)
# Out:
#        ID_1                                Paper_term_1  \
# 0   C098107                                 Flibanserin
# 1   C098107                                 Flibanserin
# 2  NEW00001  multifunctional serotonin receptor agonist
# 3  NEW00001  multifunctional serotonin receptor agonist
# 4   D063766                                     Obesity
#
#                             Full_paper_term_1  \
# 0                                 Flibanserin
# 1                                 Flibanserin
# 2  multifunctional serotonin receptor agonist
# 3  multifunctional serotonin receptor agonist
# 4                                     Obesity
#
#                               Standard_term_1  \
# 0         flibanserin [Supplementary Concept]
# 1         flibanserin [Supplementary Concept]
# 2  multifunctional serotonin receptor agonist
# 3  multifunctional serotonin receptor agonist
# 4                           Pediatric Obesity
#
#                                           Synonyms_1   Type_E1      ID_2  \
# 0                                     Benzimidazoles  CHEMICAL  NEW00000
# 1                                     Benzimidazoles  CHEMICAL   D020018
# 2                                        No synonyms  CHEMICAL  NEW00000
# 3                                        No synonyms  CHEMICAL   D020018
# 4  Obesity, Pediatric|Obesity in Childhood|Childh...   DISEASE  NEW00002
#
#                                         Paper_term_2  \
# 0  acquired generalized hypoactive sexual desire ...
# 1                                               HSDD
# 2  acquired generalized hypoactive sexual desire ...
# 3                                               HSDD
# 4                               reduced testosterone
#
#                                    Full_paper_term_2  \
# 0  acquired generalized hypoactive sexual desire ...
# 1                  hypoactive sexual desire disorder
# 2  acquired generalized hypoactive sexual desire ...
# 3                  hypoactive sexual desire disorder
# 4                               reduced testosterone
#
#                                      Standard_term_2  \
# 0  acquired generalized hypoactive sexual desire ...
# 1                 Sexual Dysfunctions, Psychological
# 2  acquired generalized hypoactive sexual desire ...
# 3                 Sexual Dysfunctions, Psychological
# 4                               reduced testosterone
#
#                                           Synonyms_2        Type_E2
# 0                                        No synonyms  MENTAL_HEALTH
# 1  Dysfunction, Psychological Sexual|Dysfunctions...        DISEASE
# 2                                        No synonyms  MENTAL_HEALTH
# 3  Dysfunction, Psychological Sexual|Dysfunctions...        DISEASE
# 4                                        No synonyms       CHEMICAL

# %%
unique_id = {}
for idx, row in term_df.iterrows():
    for k in range(1, 3):
        unique_id[row[f'ID_{k}']] = unique_id.get(row[f'ID_{k}'], {'preferred_terms': row[f'Standard_term_{k}'], 'label': row[f'Type_E{k}'], 'paper_terms': set(), 'synonyms': set()})
        if row[f'Paper_term_{k}'] != '':
          unique_id[row[f'ID_{k}']]['paper_terms'].add(row[f'Paper_term_{k}'])
        if row[f'Full_paper_term_{k}'] != '':
          unique_id[row[f'ID_{k}']]['paper_terms'].add(row[f'Full_paper_term_{k}'])
        if row[f'Synonyms_{k}'] != 'No synonyms' or row[f'Synonyms_{k}'] != '':
          unique_id[row[f'ID_{k}']]['synonyms'].update(row[f'Synonyms_{k}'].split('|'))

# %%
terms_tuple = []
for id, terms in unique_id.items():
    terms_tuple.append((id, terms['label'], terms['preferred_terms'], '|'.join(list(terms['paper_terms'].union(terms['synonyms'])))))
ID_terms_df = pd.DataFrame(terms_tuple, columns=['ID', 'Label', 'Preferred label', 'Synonyms'])
ID_terms_df.head(5)
# Out:
#          ID          Label                                    Preferred label  \
# 0   C098107       CHEMICAL                flibanserin [Supplementary Concept]
# 1  NEW00000  MENTAL_HEALTH  acquired generalized hypoactive sexual desire ...
# 2   D020018        DISEASE                 Sexual Dysfunctions, Psychological
# 3  NEW00001       CHEMICAL         multifunctional serotonin receptor agonist
# 4   D063766        DISEASE                                  Pediatric Obesity
#
#                                             Synonyms
# 0             Flibanserin|Benzimidazoles|flibanserin
# 1  acquired generalized hypoactive sexual desire ...
# 2  |Sexual Aversion Disorder|Sexual Aversion Diso...
# 3  multifunctional serotonin receptor agonist|No ...
# 4  Overweight, Adolescent|Obesity, Infantile|Adol...

# %%
ID_terms_df.to_csv("ID_to_ENTITIES_final.csv", index=False)

# %% [markdown]
# ## < ID_1, Relation, ID_2 > tuples

# %%
id_relation_df = relation_df.dropna().drop_duplicates(subset=['ID_1', 'Relation', 'ID_2']).reset_index(drop=True)
id_relation_df.to_csv("gena_data_final.csv", index=False)

# %% [markdown]
# # Final Results

# %%
import pandas as pd

# %%
id_relation_df = pd.read_csv("gena_data_final.csv")
available_data = pd.read_csv("available_fad.csv")
id_terms_df = pd.read_csv("ID_to_ENTITIES_final.csv")

# %% [markdown]
# ## 1. Numbers of unique relations

# %%
# All relations
print("Total relations:", len(id_relation_df))
# Out:
# Total relations: 43367

# %%
n_from_old_relations = len(available_data)

# New relations
print("Detected relations:", len(id_relation_df) - n_from_old_relations)

# Old relations
print("Available relations:", n_from_old_relations)
# Out:
# Detected relations: 40805
# Available relations: 2562

# %% [markdown]
# ## 2. Numbers of new relation from Old Entities

# %%
old_relations = id_relation_df.iloc[-n_from_old_relations:, :]
old_couple_dict = {(id_1, id_2): [relation] for (id_1, id_2, relation) in zip(old_relations['ID_1'], old_relations['ID_2'], old_relations['Relation'])}

new_relations = id_relation_df.iloc[:-n_from_old_relations, :]
for (id_1, id_2, relation) in zip(new_relations['ID_1'], new_relations['ID_2'], new_relations['Relation']):
  if (id_1, id_2) in old_couple_dict.keys():
    old_couple_dict[(id_1, id_2)].append(relation)

new_relation_from_old_tuples = []
for couple in old_couple_dict.keys():
  if len(old_couple_dict[couple]) > 1:
    for relation in old_couple_dict[couple][1:]:
      new_relation_from_old_tuples.append((couple[0], couple[1], old_couple_dict[couple][0], relation))

new_relation_from_old_df = pd.DataFrame(new_relation_from_old_tuples, columns=['ID_1', 'ID_2', 'Old_Relation', 'New_Relation'])
print(f"There are {len(new_relation_from_old_df)} relations for old couplez-entities.")
new_relation_from_old_df.head(len(new_relation_from_old_df))
# Out:
# There are 21 relations for old couplez-entities.
#        ID_1     ID_2 Old_Relation  \
# 0   D003024  D000380          CID
# 1   D017367  D001714          CID
# 2   D018021  D011141          CID
# 3   D003024  D009205          CID
# 4   D004837  D006323          CID
# 5   D010433  D012640          CID
# 6   D007649  D006212          CID
# 7   D007649  D006212          CID
# 8   D007649  D006212          CID
# 9   D002110  D012640          CID
# 10  D000319  D006333          CID
# 11  D018967  D006966          CID
# 12  D010665  D020521          CID
# 13  D018021  D001930          CID
# 14  D014700  D001281          CID
# 15  D000638  D007037          CID
# 16  D014635  D022124          CID
# 17  D000638  D001919          CID
# 18  D002110  D001008          CID
# 19  D003024  D020820          CID
# 20  D016291  D012640          CID
#
#                                          New_Relation
# 0               cause fatal hematopoietic toxicity as
# 1                      be prescribed to patients with
# 2                                             include
# 3                         be effective medication for
# 4                                     have the use to
# 5                                              induce
# 6                                               cause
# 7                                   be complicated by
# 8                                              induce
# 9                               have the influence on
# 10                          be mainstay treatment for
# 11  be reserved given potential development of ath...
# 12                                        precipitate
# 13                         exert beneficial effect on
# 14               decrease ventricular response during
# 15                                        be given in
# 16                                              cause
# 17                                            produce
# 18                                            produce
# 19                     show efficacy as treatment for
# 20                             prevent development of

# %% [markdown]
# ## 3. Numbers of totally new relations

# %%
totally_relations = len(new_relations) - len(new_relation_from_old_df)
print("Totally new relations:", totally_relations)
# Out:
# Totally new relations: 40784

# %% [markdown]
# ## 4. Numbers of New Entities

# %%
print("Total numbers of entities:", len(id_terms_df))
# Out:
# Total numbers of entities: 28598

# %%
new_id = len(ID_terms_df[ID_terms_df['ID'].str.startswith('NEW')])
print("Numbers of new entities:", new_id)
# Out:
# Numbers of new entities: 21831

# %% [markdown]
# ## 5. Precision

# %%
result_1 = pd.read_excel("sample_test_final_R01.xlsx")
result_2 = pd.read_excel("sample_test_final_R02.xlsx")

# %% [markdown]
# ### 5.a. Precision of Entities

# %%
import sklearn
from sklearn.metrics import cohen_kappa_score

print("Precision of Entities by Annotator 1: ", (sum(result_1['E1_Result']) + sum(result_1['E2_Result']))/(2.0*len(result_1)))
print("Precision of Entities by Annotator 2: ", (sum(result_2['E1_Result']) + sum(result_2['E2_Result']))/(2.0*len(result_2)))

print("IAA of Entities: ", cohen_kappa_score(result_1['E1_Result'].tolist() + result_1['E2_Result'].tolist(), result_2['E1_Result'].tolist() + result_2['E2_Result'].tolist()))
# Out:
# Precision of Entities by Annotator 1:  0.952
# Precision of Entities by Annotator 2:  0.958
# IAA of Entities:  0.8836776474967429

# %% [markdown]
# ### 5.b. Precision of Relations

# %%
print("Precision of Relations by Annotator 1:", result_1['Relation_Result'].mean())
print("Precision of Relations by Annotator 2:", result_2['Relation_Result'].mean())

print("IAA of Entities: ", cohen_kappa_score(result_1['Relation_Result'].tolist(), result_2['Relation_Result']))
# Out:
# Precision of Relations by Annotator 1: 0.804
# Precision of Relations by Annotator 2: 0.816
# IAA of Entities:  0.8570834632574577
