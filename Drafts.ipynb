# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([2117, 14, 38523])
relationship_labels = ["Old relationships", "Sub-relationships", "New relationships"]
explode = [0, 0.2, 0.3]

plt.pie(y, labels = relationship_labels, explode = explode, autopct='%1.1f%%')
plt.savefig('relationships_gena.png')
plt.show()
